# %%
import pandas as pd

# %% [markdown]
# ### Load and process sensor readings

# %%
sensor_readings = pd.read_csv("speed_readings.csv")
sensor_readings = sensor_readings.pivot(index="Timestamp", columns="sensor_id", values="measurement")
sensor_readings
# Out:
# sensor_id               716328     716331     716337     716339     716554  \
# Timestamp
# 2012-03-01 00:00:00  66.875000  67.500000  63.125000  64.250000  63.500000
# 2012-03-01 00:05:00  67.444444  65.444444  63.777778  66.444444  56.000000
# 2012-03-01 00:10:00  65.000000  67.875000  63.875000  64.750000  59.125000
# 2012-03-01 00:15:00   0.000000   0.000000   0.000000   0.000000   0.000000
# 2012-03-01 00:20:00   0.000000   0.000000   0.000000   0.000000   0.000000
# ...                        ...        ...        ...        ...        ...
# 2012-06-27 23:35:00  66.333333  64.333333  65.777778  63.444444  59.888889
# 2012-06-27 23:40:00  63.750000  64.250000  66.125000  63.125000  55.750000
# 2012-06-27 23:45:00  66.888889  59.000000  64.444444  64.444444  55.333333
# 2012-06-27 23:50:00  65.000000  65.625000  62.375000  64.875000  52.625000
# 2012-06-27 23:55:00  66.555556  65.888889  65.111111  64.333333  57.444444
#
# sensor_id               716571     716939     716941     716942  716943  ...  \
# Timestamp                                                                ...
# 2012-03-01 00:00:00  67.000000  53.625000  58.125000  62.125000  55.000  ...
# 2012-03-01 00:05:00  65.888889  59.888889  56.222222  62.000000  50.000  ...
# 2012-03-01 00:10:00  61.375000  56.000000  59.125000  63.125000  54.875  ...
# 2012-03-01 00:15:00   0.000000   0.000000   0.000000   0.000000   0.000  ...
# 2012-03-01 00:20:00   0.000000   0.000000   0.000000   0.000000   0.000  ...
# ...                        ...        ...        ...        ...     ...  ...
# 2012-06-27 23:35:00  59.555556  53.444444  60.333333  57.000000  53.000  ...
# 2012-06-27 23:40:00  66.750000  56.500000  59.125000  58.125000  51.625  ...
# 2012-06-27 23:45:00  68.333333  52.222222  61.333333  65.333333  55.000  ...
# 2012-06-27 23:50:00  66.875000  60.750000  55.875000  58.500000  49.250  ...
# 2012-06-27 23:55:00  65.555556  57.777778  58.555556  58.444444  43.000  ...
#
# sensor_id               773953     773954     773974     773975     773995  \
# Timestamp
# 2012-03-01 00:00:00  55.750000  63.875000  52.125000  64.750000  63.125000
# 2012-03-01 00:05:00  60.888889  62.333333  52.333333  62.222222  58.555556
# 2012-03-01 00:10:00  62.375000  61.500000  56.125000  63.500000  64.125000
# 2012-03-01 00:15:00   0.000000   0.000000   0.000000   0.000000   0.000000
# 2012-03-01 00:20:00   0.000000   0.000000   0.000000   0.000000   0.000000
# ...                        ...        ...        ...        ...        ...
# 2012-06-27 23:35:00  62.666667  62.555556  54.777778  64.888889  58.222222
# 2012-06-27 23:40:00  62.500000  62.875000  52.500000  63.500000  65.250000
# 2012-06-27 23:45:00  59.888889  63.333333  53.222222  64.333333  65.555556
# 2012-06-27 23:50:00  62.750000  53.375000  53.250000  62.375000  64.625000
# 2012-06-27 23:55:00  63.222222  62.555556  55.333333  65.000000  65.000000
#
# sensor_id               773996     774011     774012     774067     774204
# Timestamp
# 2012-03-01 00:00:00  61.375000  67.750000  55.875000  52.500000  64.500000
# 2012-03-01 00:05:00  58.666667  64.111111  66.444444  34.666667  66.666667
# 2012-03-01 00:10:00  59.500000  67.125000  65.750000  50.000000  56.500000
# 2012-03-01 00:15:00   0.000000   0.000000   0.000000   0.000000   0.000000
# 2012-03-01 00:20:00   0.000000   0.000000   0.000000   0.000000   0.000000
# ...                        ...        ...        ...        ...        ...
# 2012-06-27 23:35:00  60.444444  66.666667  64.888889  61.777778  65.111111
# 2012-06-27 23:40:00  65.125000  65.750000  67.875000  62.625000  60.125000
# 2012-06-27 23:45:00  62.888889  67.444444  67.888889  60.333333  64.333333
# 2012-06-27 23:50:00  57.875000  67.125000  64.000000  57.250000  61.625000
# 2012-06-27 23:55:00  61.666667  65.222222  65.888889  56.000000  64.888889
#
# [34272 rows x 207 columns]

# %% [markdown]
# ## Imputation

# %% [markdown]
# ### Split train/val, and scale

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import StandardScaler
import joblib

def split_scale(measurements, feature, cluster):

    # Step 1: Split the full data (X_seq or X_ori) into train and validation sets
    X_train_full, X_val_full = train_test_split(measurements, test_size=0.2, shuffle = False, random_state=42)

    scaler = StandardScaler()

    # Fit and transform training data
    X_train_full_scaled = X_train_full.copy()
    X_train_full_scaled = scaler.fit_transform(X_train_full)
    X_train_full_scaled = pd.DataFrame(X_train_full_scaled, columns=X_train_full.columns, index=X_train_full.index)

    # Save scaler with specific name for later rescaling
    joblib.dump(scaler, f"{feature}_scaler_{cluster}.pkl")

    # Now, apply ONLY transformation (not fitting) on val data
    X_val_full_scaled = X_val_full.copy()
    X_val_full_scaled = scaler.transform(X_val_full)
    X_val_full_scaled = pd.DataFrame(X_val_full_scaled, columns=X_val_full.columns, index=X_val_full.index)

    return X_train_full_scaled, X_val_full_scaled, X_train_full, X_val_full

# %%
speeds_c0 = sensor_readings[[716328, 716331, 716337, 716339, 716571, 716939, 716941, 716942, 716943, 716949, 716951, 716953, 716955, 716956, 716958, 716960, 717445, 717446, 717447, 717450, 717452, 717453, 717456, 717458, 717459, 717460, 717461, 717462, 717463, 717465, 717466, 717468, 717469, 717472, 717473, 717480, 717481, 717483, 717486, 717488, 717489, 717490, 717491, 717492, 717493, 717495, 717497, 717498, 717499, 717502, 717504, 717508, 717510, 717513, 717570, 717571, 717572, 717573, 717576, 717578, 717592, 717595, 717608, 717610, 717804, 717816, 717818, 717819, 717821, 717823, 717825, 718045, 718064, 718066, 718072, 718089, 718090, 718141, 718204, 718371, 718379, 718499, 737529]]
speeds_c1 =  sensor_readings[[769345, 769346, 769358, 769359, 769372, 769373, 769388, 769402, 769403, 769405, 769418, 769430, 769431, 769443, 769444, 769467, 771667, 771673, 772140, 772151, 772167, 772168, 772178, 772513, 772596, 772597, 772669, 773012, 773013, 773023, 773024, 773062, 773869, 773880, 773904, 773906, 773916, 773927, 773939, 773953, 773954, 773974, 773975, 773995, 773996, 774011, 774012, 774067]]
speeds_c2 = sensor_readings[[759591, 759602, 760024, 760650, 761003, 761599, 761604, 762329, 763995, 764101, 764106, 764120, 764424, 764760, 764766, 764781, 764794, 764853, 764858, 764949, 765099, 765164, 765171, 765176, 765182, 765265, 765273, 765604, 767053, 767350, 767351, 767366, 767454, 767455, 767494, 767495, 767509, 767523, 767541, 767542, 767554, 767572, 767573, 767620, 767621, 767750, 767751, 768066, 768469]]
speeds_all = sensor_readings.copy()

# Initialize the containers
X_train_full_scaled = {}
X_val_full_scaled = {}
X_train_full_unscaled = {}
X_val_full_unscaled = {}
clusters = [speeds_c0, speeds_c1, speeds_c2, speeds_all]

# Iterate over the clusters
for i, flow_cluster in enumerate(clusters):
    X_train_full_scaled[i], X_val_full_scaled[i], X_train_full_unscaled[i], X_val_full_unscaled[i] = split_scale(flow_cluster, "speed", i)

# %%
X_train_full_scaled[1]
# Out:
# sensor_id              769345    769346    769358    769359    769372  \
# Timestamp
# 2012-03-01 00:00:00  0.686119  0.552111  0.720071  0.509519  0.332267
# 2012-03-01 00:05:00  0.820647  0.701854  0.702033  0.792156  0.552466
# 2012-03-01 00:10:00  0.800468  0.737999  0.734188  0.461001  0.508426
# 2012-03-01 00:15:00 -2.838507 -2.880178 -2.886868 -2.824367 -2.964422
# 2012-03-01 00:20:00 -2.838507 -2.880178 -2.886868 -2.824367 -2.964422
# ...                       ...       ...       ...       ...       ...
# 2012-06-04 04:20:00  0.322894  0.492361  0.310673  0.599624  0.300810
# 2012-06-04 04:25:00  0.288515  0.471707  0.388317  0.311596  0.318286
# 2012-06-04 04:30:00  0.242178  0.339668  0.190677  0.336240  0.458095
# 2012-06-04 04:35:00  0.450696  0.651694  0.204794  0.627349  0.432929
# 2012-06-04 04:40:00  0.390158  0.636941  0.425963  0.631970  0.351840
#
# sensor_id              769373    769388    769402    769403    769405  ...  \
# Timestamp                                                              ...
# 2012-03-01 00:00:00  0.476704  0.333409  0.417810  0.374391  0.759628  ...
# 2012-03-01 00:05:00  0.525629  0.484914  0.659686  0.289010  0.561899  ...
# 2012-03-01 00:10:00  0.482820  0.511263  0.592264  0.483131  0.811023  ...
# 2012-03-01 00:15:00 -2.550522 -3.098513 -3.351912 -3.525756 -2.047833  ...
# 2012-03-01 00:20:00 -2.550522 -3.098513 -3.351912 -3.525756 -2.047833  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2012-06-04 04:20:00  0.599016  0.419043  0.561924  0.367142  0.605442  ...
# 2012-06-04 04:25:00  0.586106  0.402941  0.234929  0.192352  0.641847  ...
# 2012-06-04 04:30:00  0.592901  0.274125  0.304036  0.280150  0.631140  ...
# 2012-06-04 04:35:00  0.525629  0.247776  0.357131  0.164160  0.855994  ...
# 2012-06-04 04:40:00  0.645903  0.490770  0.430452  0.437219  0.841717  ...
#
# sensor_id              773939    773953    773954    773974    773975  \
# Timestamp
# 2012-03-01 00:00:00  0.571499  0.027902  0.442671 -0.068183  0.269287
# 2012-03-01 00:05:00  0.810589  0.339414  0.342273 -0.052679  0.105760
# 2012-03-01 00:10:00  0.340948  0.429500  0.288004  0.229505  0.188422
# 2012-03-01 00:15:00 -2.239028 -3.351575 -3.717078 -3.947432 -3.919539
# 2012-03-01 00:20:00 -2.239028 -3.351575 -3.717078 -3.947432 -3.919539
# ...                       ...       ...       ...       ...       ...
# 2012-06-04 04:20:00 -0.169558  0.520427 -0.062034  0.843487  0.139903
# 2012-06-04 04:25:00  0.098199  0.366355 -0.272780  0.311162 -0.181762
# 2012-06-04 04:30:00 -0.087218  0.399190  0.003089  0.248110  0.059037
# 2012-06-04 04:35:00 -0.136622  0.384036  0.141476 -0.449596 -0.175472
# 2012-06-04 04:40:00  0.103078  0.366355 -0.323432  0.195395 -0.138634
#
# sensor_id              773995    773996    774011    774012    774067
# Timestamp
# 2012-03-01 00:00:00  0.279438  0.265665  0.353572 -0.332757 -0.152326
# 2012-03-01 00:05:00  0.004178  0.098432  0.142309  0.273987 -1.073832
# 2012-03-01 00:10:00  0.339677  0.149888  0.317287  0.234122 -0.281509
# 2012-03-01 00:15:00 -3.523162 -3.524103 -3.579790 -3.540285 -2.865170
# 2012-03-01 00:20:00 -3.523162 -3.524103 -3.579790 -3.540285 -2.865170
# ...                       ...       ...       ...       ...       ...
# 2012-06-04 04:20:00  0.445095  0.010956 -0.023798 -0.124662 -0.442988
# 2012-06-04 04:25:00  0.211668 -0.025064  0.045548  0.089014 -0.011660
# 2012-06-04 04:30:00  0.286967  0.327413  0.222944  0.155190 -0.920965
# 2012-06-04 04:35:00  0.362266  0.041830  0.288258 -0.067256  0.370865
# 2012-06-04 04:40:00  0.325454  0.228788  0.277776  0.057122 -0.218353
#
# [27417 rows x 48 columns]

# %%
def sliding_window_3d(data, window_size, stride):
    """
    Converts a long time series [1, T, F] into [N, window_size, F]
    """
    data = data.squeeze(0)  # [T, F]
    total_steps, n_features = data.shape
    windows = []

    for i in range(0, total_steps - window_size + 1, stride):
        window = data[i:i+window_size]
        windows.append(window)

    return np.stack(windows)

# %% [markdown]
# ### Introduce MCAR Missingness

# %%
from pygrinder import mar_logistic

missing_rates = [0.05, 0.2, 0.6, 0.99]

# Training and validation sets for each cluster
X_train_incomplete = {}
X_val_incomplete = {}
train_masks = {}
val_masks = {}
X_train_seq = {}
X_val_seq = {}
train_masks_seq = {}
val_masks_seq = {}

# Full tensors for each cluster
X_train_full_tensor = {}
X_val_full_tensor = {}
X_val_full_seq = {}
X_train_full_seq = {}
X_train_full_unscaled_seq_tensor = {}
X_val_full_unscaled_seq_tensor = {}


n_steps = 1008 # 3.5 days each window
stride = 288 # 1 day stride

for cluster_id, flow_cluster in enumerate(clusters):
    X_train_incomplete[cluster_id] = {}
    X_val_incomplete[cluster_id] = {}
    train_masks[cluster_id] = {}
    val_masks[cluster_id] = {}
    X_train_seq[cluster_id] = {}
    X_val_seq[cluster_id] = {}
    train_masks_seq[cluster_id] = {}
    val_masks_seq[cluster_id] = {}

    for rate in missing_rates:
        key = int(rate * 100)

        # Introduce missingness per cluster & rate
        print(f"Introducing {rate*100}% missingness for cluster {cluster_id} with key {key}")

        # Apply MNAR-x missingness
        X_train_incomplete[cluster_id][key] = mar_logistic(X_train_full_scaled[cluster_id].values, obs_rate=0.4, missing_rate=rate)
        X_val_incomplete[cluster_id][key] = mar_logistic(X_val_full_scaled[cluster_id].values, obs_rate=0.4, missing_rate=rate)

        # Masks for missingness
        train_masks[cluster_id][key] = np.isnan(X_train_incomplete[cluster_id][key])
        val_masks[cluster_id][key] = np.isnan(X_val_incomplete[cluster_id][key])

        actual_missing_rate = train_masks[cluster_id][key].mean()
        print(f"Actual missing rate: {actual_missing_rate:.2%}")
        
        # Expand dims for batch axis (needed for sliding window)
        X_train_tensor = np.expand_dims(X_train_incomplete[cluster_id][key], axis=0)
        X_val_tensor = np.expand_dims(X_val_incomplete[cluster_id][key], axis=0)
        train_mask_tensor = np.expand_dims(train_masks[cluster_id][key], axis=0)
        val_mask_tensor = np.expand_dims(val_masks[cluster_id][key], axis=0)

        # Sliding window on data
        X_train_seq[cluster_id][key] = sliding_window_3d(X_train_tensor, window_size=n_steps, stride=stride)
        X_val_seq[cluster_id][key] = sliding_window_3d(X_val_tensor, window_size=n_steps, stride=stride)

        # Sliding window on masks
        train_masks_seq[cluster_id][key] = sliding_window_3d(train_mask_tensor, window_size=n_steps, stride=stride)
        val_masks_seq[cluster_id][key] = sliding_window_3d(val_mask_tensor, window_size=n_steps, stride=stride)


    # Expand full training tensors
    X_train_full_tensor[cluster_id] = np.expand_dims(X_train_full_scaled[cluster_id].values, axis = 0)

    # Expand full validation tensors
    X_val_full_tensor[cluster_id] = np.expand_dims(X_val_full_scaled[cluster_id].values, axis = 0)

    # Convert scaled data to tensor
    X_val_full_seq[cluster_id] = sliding_window_3d(X_val_full_tensor[cluster_id], window_size=n_steps, stride=stride)
    X_train_full_seq[cluster_id] = sliding_window_3d(X_train_full_tensor[cluster_id], window_size=n_steps, stride=stride)

    # Convert unscaled data to tensor
    X_train_full_unscaled_values = np.expand_dims(X_train_full_unscaled[cluster_id].values, axis=0)
    X_train_full_unscaled_seq_tensor[cluster_id] = sliding_window_3d(X_train_full_unscaled_values, window_size=n_steps, stride=stride)

    X_val_full_unscaled_values = np.expand_dims(X_val_full_unscaled[cluster_id].values, axis=0)
    X_val_full_unscaled_seq_tensor[cluster_id] = sliding_window_3d(X_val_full_unscaled_values, window_size=n_steps, stride=stride)
# Out:
# Introducing 5.0% missingness for cluster 0 with key 5
# Actual missing rate: 3.01%
# Introducing 20.0% missingness for cluster 0 with key 20
# Actual missing rate: 12.00%
# Introducing 60.0% missingness for cluster 0 with key 60
# Actual missing rate: 36.15%
# Introducing 99.0% missingness for cluster 0 with key 99
# Actual missing rate: 59.63%
# Introducing 5.0% missingness for cluster 1 with key 5
# Actual missing rate: 3.02%
# Introducing 20.0% missingness for cluster 1 with key 20
# Actual missing rate: 12.13%
# Introducing 60.0% missingness for cluster 1 with key 60
# Actual missing rate: 36.31%
# Introducing 99.0% missingness for cluster 1 with key 99
# Actual missing rate: 59.82%
# Introducing 5.0% missingness for cluster 2 with key 5
# Actual missing rate: 3.07%
# Introducing 20.0% missingness for cluster 2 with key 20
# Actual missing rate: 12.23%
# Introducing 60.0% missingness for cluster 2 with key 60
# Actual missing rate: 36.78%
# Introducing 99.0% missingness for cluster 2 with key 99
# Actual missing rate: 60.62%
# Introducing 5.0% missingness for cluster 3 with key 5
# Actual missing rate: 3.01%
# Introducing 20.0% missingness for cluster 3 with key 20
# Actual missing rate: 12.08%
# Introducing 60.0% missingness for cluster 3 with key 60
# Actual missing rate: 36.22%
# Introducing 99.0% missingness for cluster 3 with key 99
# Actual missing rate: 59.78%

# %%
# Step 3: Prepare the final datasets with 'X' (incomplete) and 'X_ori' (full data)

# 20 percent missing
train_data, val_data = {}, {}

for cluster_id in range(len(clusters)):
    train_data[cluster_id] = {}
    val_data[cluster_id] = {}
    
    for rate in missing_rates:
        key = int(rate * 100)
        
        # Prepare the train and validation data dictionaries for each missing rate
        train_data[cluster_id][key] = {"X": X_train_seq[cluster_id][key]}
        val_data[cluster_id][key] = {"X": X_val_seq[cluster_id][key], "X_ori": X_val_full_seq[cluster_id]}

# %%
def mean_impute(X_incomplete):
    """
    Impute missing values using feature-wise mean over the entire dataset.
    Assumes input shape is [n_samples, n_steps, n_features].
    """
    X_imputed = X_incomplete.copy()
    n_features = X_imputed.shape[2]

    for f in range(n_features):
        feature_data = X_imputed[:, :, f]
        mean_val = np.nanmean(feature_data)
        feature_data[np.isnan(feature_data)] = mean_val
        X_imputed[:, :, f] = feature_data

    return X_imputed

# %%
# Dictionary to hold results
mean_imputed_results = {}
missing_masks = {}

for cluster_idx, cluster_data in enumerate(X_val_seq):
    mean_imputed_results[cluster_idx] = {}
    missing_masks[cluster_idx] = {}
    
    for rate in missing_rates:
        key = int(rate * 100)
        X_missing = X_val_seq[cluster_idx][key]
        
        # Impute using mean
        X_imputed = mean_impute(X_missing)
        mean_imputed_results[cluster_idx][key] = X_imputed

        # Create missing mask
        missing_mask = np.isnan(X_missing)
        missing_masks[cluster_idx][key] = missing_mask

# %%
import joblib

imputed_unscaled_mean = {}

for cluster_id in range(len(clusters)):
    imputed_unscaled_mean[cluster_id] = {}
    
    scaler = joblib.load(f"speed_scaler_{cluster_id}.pkl")
    print(f"{type(scaler)}")

# Unscale the imputed values for each cluster and missing rate
    for rate in missing_rates:
        key = int(rate * 100)
        n_samples, n_steps, n_features = mean_imputed_results[cluster_id][key].shape
        tensor_2d = mean_imputed_results[cluster_id][key].reshape(-1, n_features)  # Flatten time dimension
        tensor_2d_unscaled = scaler.inverse_transform(tensor_2d)
        imputed_unscaled_mean[cluster_id][key] = tensor_2d_unscaled.reshape(n_samples, n_steps, n_features)
# Out:
# <class 'sklearn.preprocessing._data.StandardScaler'>
# <class 'sklearn.preprocessing._data.StandardScaler'>
# <class 'sklearn.preprocessing._data.StandardScaler'>
# <class 'sklearn.preprocessing._data.StandardScaler'>

# %%
# Calculate MAE for imputation evaluation

# Calculate MAE for imputation evaluation

mae_mean = {}
for cluster_id in range(len(clusters)):
    mae_mean[cluster_id] = {}

    for rate in missing_rates:
        key = int(rate * 100)
        mae_mean[cluster_id][key] = np.mean(np.abs(imputed_unscaled_mean[cluster_id][key][val_masks_seq[cluster_id][key]] - X_val_full_unscaled_seq_tensor[cluster_id][val_masks_seq[cluster_id][key]]))
        print(f"MAE Cluster {cluster_id} Rate {rate*100}% (MAE): {mae_mean[cluster_id][key]}")
# Out:
# MAE Cluster 0 Rate 5.0% (MAE): 20.583473875220758
# MAE Cluster 0 Rate 20.0% (MAE): 21.26118512690074
# MAE Cluster 0 Rate 60.0% (MAE): 19.529312914429504
# MAE Cluster 0 Rate 99.0% (MAE): 21.48795134336283
# MAE Cluster 1 Rate 5.0% (MAE): 21.596058096156053
# MAE Cluster 1 Rate 20.0% (MAE): 19.170695185671015
# MAE Cluster 1 Rate 60.0% (MAE): 18.312942116361988
# MAE Cluster 1 Rate 99.0% (MAE): 23.61184195661565
# MAE Cluster 2 Rate 5.0% (MAE): 23.03728985937693
# MAE Cluster 2 Rate 20.0% (MAE): 20.761503163145665
# MAE Cluster 2 Rate 60.0% (MAE): 17.364681562128837
# MAE Cluster 2 Rate 99.0% (MAE): 24.42508970197981
# MAE Cluster 3 Rate 5.0% (MAE): 21.07463136349324
# MAE Cluster 3 Rate 20.0% (MAE): 20.052300132890508
# MAE Cluster 3 Rate 60.0% (MAE): 18.33299966419786
# MAE Cluster 3 Rate 99.0% (MAE): 23.252902685625003

# %%
#SMAPE for each percentage of missingness
smape = {}
for cluster_id in range(len(clusters)):
    smape[cluster_id] = {}
    for rate in missing_rates:
        key = int(rate * 100)
        numerator = np.abs((imputed_unscaled_mean[cluster_id][key][val_masks_seq[cluster_id][key]] - X_val_full_unscaled_seq_tensor[cluster_id][val_masks_seq[cluster_id][key]]))
        denominator = np.abs(imputed_unscaled_mean[cluster_id][key][val_masks_seq[cluster_id][key]]) + np.abs(X_val_full_unscaled_seq_tensor[cluster_id][val_masks_seq[cluster_id][key]]) + 1e-8
        smape[cluster_id][key] = 100 * np.mean(2 * numerator / denominator)
        print(f"SMAPE Cluster {cluster_id} Rate {rate*100}%: {smape[cluster_id][key]:.2f}%")
# Out:
# SMAPE Cluster 0 Rate 5.0%: 63.16%
# SMAPE Cluster 0 Rate 20.0%: 63.23%
# SMAPE Cluster 0 Rate 60.0%: 53.67%
# SMAPE Cluster 0 Rate 99.0%: 63.15%
# SMAPE Cluster 1 Rate 5.0%: 67.76%
# SMAPE Cluster 1 Rate 20.0%: 55.31%
# SMAPE Cluster 1 Rate 60.0%: 52.72%
# SMAPE Cluster 1 Rate 99.0%: 76.84%
# SMAPE Cluster 2 Rate 5.0%: 71.41%
# SMAPE Cluster 2 Rate 20.0%: 59.48%
# SMAPE Cluster 2 Rate 60.0%: 46.32%
# SMAPE Cluster 2 Rate 99.0%: 68.30%
# SMAPE Cluster 3 Rate 5.0%: 64.80%
# SMAPE Cluster 3 Rate 20.0%: 57.82%
# SMAPE Cluster 3 Rate 60.0%: 48.41%
# SMAPE Cluster 3 Rate 99.0%: 68.59%

# %%
from pypots.imputation import BRITS
from pypots.nn.modules.loss import MAE, MSE
from pypots.optim.adam import Adam
import torch

def intialize_BRITS(n_steps, num_features, rnn_hidden_size):

    # Basic configuration
    model = BRITS(
        n_steps=n_steps,
        n_features=num_features,
        rnn_hidden_size=rnn_hidden_size,               # Reasonable hidden size
        batch_size=32,                    # Standard for most datasets
        epochs=25,                       # Higher epochs for better convergence
        patience=5,                      # Early stopping if no improvement
        training_loss=MAE,                # MAE often performs well for imputation
        validation_metric=MSE,           # Use MSE for validation comparison
        optimizer=Adam,                   # Adam optimizer (default)
        num_workers=0,                    # Adjust if using DataLoader with multiprocessing
        device="cuda" if torch.cuda.is_available() else "cpu",  # Use GPU if available
        saving_path="./brits_model",     # Directory to save model checkpoints
        model_saving_strategy="best",    # Save best model only
        verbose=True                      # Print training progress
    )

    return model

# %%
len(clusters[3].columns)
# Out:
# 207

# %%
models = {}
rnn_hidden = 0
# Initialize and fit BRITS models for each missing rate

for cluster_id in range(len(clusters)):
    print(f"Training BRITS models for cluster {cluster_id}...")
    models[cluster_id] = {}
    for rate in missing_rates:
        print(f"Training model for missing rate {rate} in cluster {cluster_id}...")
        key = int(rate * 100)

        _, n_steps, n_features = train_data[cluster_id][key]["X"].shape
        
        # Reduce complexity of model for less features
       # if cluster_id != len(clusters) - 1:
        #    rnn_hidden = 16
        #else:
        rnn_hidden = 16
        
        models[cluster_id][key] = intialize_BRITS(n_steps, n_features, rnn_hidden)
        models[cluster_id][key].fit(train_data[cluster_id][key], val_set=val_data[cluster_id][key])
# Out:
# 2025-06-19 11:15:34 [INFO]: Using the given device: cpu
# 2025-06-19 11:15:34 [INFO]: Model files will be saved to ./brits_model\20250619_T111534
# 2025-06-19 11:15:34 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T111534\tensorboard
# 2025-06-19 11:15:34 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 11:15:34 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 11:15:34 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 117,664
# Training BRITS models for cluster 0...
# Training model for missing rate 0.05 in cluster 0...
# 2025-06-19 11:15:59 [INFO]: Epoch 001 - training loss (MAE): 1.4337, validation MSE: 1.8982
# 2025-06-19 11:16:20 [INFO]: Epoch 002 - training loss (MAE): 1.3177, validation MSE: 1.6153
# 2025-06-19 11:16:39 [INFO]: Epoch 003 - training loss (MAE): 1.2241, validation MSE: 1.4188
# 2025-06-19 11:16:58 [INFO]: Epoch 004 - training loss (MAE): 1.1491, validation MSE: 1.2747
# 2025-06-19 11:17:17 [INFO]: Epoch 005 - training loss (MAE): 1.0953, validation MSE: 1.1684
# 2025-06-19 11:17:37 [INFO]: Epoch 006 - training loss (MAE): 1.0515, validation MSE: 1.0799
# 2025-06-19 11:17:55 [INFO]: Epoch 007 - training loss (MAE): 1.0169, validation MSE: 1.0163
# 2025-06-19 11:18:14 [INFO]: Epoch 008 - training loss (MAE): 0.9889, validation MSE: 0.9659
# 2025-06-19 11:18:37 [INFO]: Epoch 009 - training loss (MAE): 0.9635, validation MSE: 0.9236
# 2025-06-19 11:19:01 [INFO]: Epoch 010 - training loss (MAE): 0.9391, validation MSE: 0.8868
# 2025-06-19 11:19:24 [INFO]: Epoch 011 - training loss (MAE): 0.9221, validation MSE: 0.8576
# 2025-06-19 11:19:48 [INFO]: Epoch 012 - training loss (MAE): 0.9030, validation MSE: 0.8267
# 2025-06-19 11:20:07 [INFO]: Epoch 013 - training loss (MAE): 0.8854, validation MSE: 0.7902
# 2025-06-19 11:20:25 [INFO]: Epoch 014 - training loss (MAE): 0.8699, validation MSE: 0.7515
# 2025-06-19 11:20:44 [INFO]: Epoch 015 - training loss (MAE): 0.8525, validation MSE: 0.7066
# 2025-06-19 11:21:02 [INFO]: Epoch 016 - training loss (MAE): 0.8370, validation MSE: 0.6627
# 2025-06-19 11:21:21 [INFO]: Epoch 017 - training loss (MAE): 0.8247, validation MSE: 0.6250
# 2025-06-19 11:21:39 [INFO]: Epoch 018 - training loss (MAE): 0.8114, validation MSE: 0.5930
# 2025-06-19 11:21:57 [INFO]: Epoch 019 - training loss (MAE): 0.7985, validation MSE: 0.5627
# 2025-06-19 11:22:15 [INFO]: Epoch 020 - training loss (MAE): 0.7871, validation MSE: 0.5385
# 2025-06-19 11:22:33 [INFO]: Epoch 021 - training loss (MAE): 0.7763, validation MSE: 0.5218
# 2025-06-19 11:22:50 [INFO]: Epoch 022 - training loss (MAE): 0.7671, validation MSE: 0.5091
# 2025-06-19 11:23:08 [INFO]: Epoch 023 - training loss (MAE): 0.7565, validation MSE: 0.4956
# 2025-06-19 11:23:27 [INFO]: Epoch 024 - training loss (MAE): 0.7483, validation MSE: 0.4810
# 2025-06-19 11:23:45 [INFO]: Epoch 025 - training loss (MAE): 0.7388, validation MSE: 0.4686
# 2025-06-19 11:23:45 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 11:23:45 [INFO]: Saved the model to ./brits_model\20250619_T111534\BRITS.pypots
# 2025-06-19 11:23:45 [INFO]: Using the given device: cpu
# 2025-06-19 11:23:45 [INFO]: Model files will be saved to ./brits_model\20250619_T112345
# 2025-06-19 11:23:45 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T112345\tensorboard
# 2025-06-19 11:23:45 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 11:23:45 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 11:23:45 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 117,664
# Training model for missing rate 0.2 in cluster 0...
# 2025-06-19 11:24:12 [INFO]: Epoch 001 - training loss (MAE): 1.4086, validation MSE: 1.7265
# 2025-06-19 11:24:30 [INFO]: Epoch 002 - training loss (MAE): 1.3033, validation MSE: 1.4661
# 2025-06-19 11:24:49 [INFO]: Epoch 003 - training loss (MAE): 1.2128, validation MSE: 1.2919
# 2025-06-19 11:25:07 [INFO]: Epoch 004 - training loss (MAE): 1.1403, validation MSE: 1.1910
# 2025-06-19 11:25:26 [INFO]: Epoch 005 - training loss (MAE): 1.0864, validation MSE: 1.1320
# 2025-06-19 11:25:45 [INFO]: Epoch 006 - training loss (MAE): 1.0462, validation MSE: 1.0961
# 2025-06-19 11:26:05 [INFO]: Epoch 007 - training loss (MAE): 1.0122, validation MSE: 1.0638
# 2025-06-19 11:26:23 [INFO]: Epoch 008 - training loss (MAE): 0.9854, validation MSE: 1.0378
# 2025-06-19 11:26:41 [INFO]: Epoch 009 - training loss (MAE): 0.9561, validation MSE: 1.0104
# 2025-06-19 11:26:59 [INFO]: Epoch 010 - training loss (MAE): 0.9372, validation MSE: 0.9920
# 2025-06-19 11:27:17 [INFO]: Epoch 011 - training loss (MAE): 0.9158, validation MSE: 0.9680
# 2025-06-19 11:27:35 [INFO]: Epoch 012 - training loss (MAE): 0.8945, validation MSE: 0.9418
# 2025-06-19 11:27:53 [INFO]: Epoch 013 - training loss (MAE): 0.8762, validation MSE: 0.9168
# 2025-06-19 11:28:11 [INFO]: Epoch 014 - training loss (MAE): 0.8618, validation MSE: 0.8899
# 2025-06-19 11:28:29 [INFO]: Epoch 015 - training loss (MAE): 0.8462, validation MSE: 0.8577
# 2025-06-19 11:28:47 [INFO]: Epoch 016 - training loss (MAE): 0.8322, validation MSE: 0.8280
# 2025-06-19 11:29:05 [INFO]: Epoch 017 - training loss (MAE): 0.8187, validation MSE: 0.8010
# 2025-06-19 11:29:23 [INFO]: Epoch 018 - training loss (MAE): 0.8014, validation MSE: 0.7684
# 2025-06-19 11:29:41 [INFO]: Epoch 019 - training loss (MAE): 0.7910, validation MSE: 0.7436
# 2025-06-19 11:30:02 [INFO]: Epoch 020 - training loss (MAE): 0.7799, validation MSE: 0.7261
# 2025-06-19 11:30:20 [INFO]: Epoch 021 - training loss (MAE): 0.7706, validation MSE: 0.7110
# 2025-06-19 11:30:39 [INFO]: Epoch 022 - training loss (MAE): 0.7575, validation MSE: 0.6924
# 2025-06-19 11:30:57 [INFO]: Epoch 023 - training loss (MAE): 0.7500, validation MSE: 0.6779
# 2025-06-19 11:31:16 [INFO]: Epoch 024 - training loss (MAE): 0.7409, validation MSE: 0.6645
# 2025-06-19 11:31:35 [INFO]: Epoch 025 - training loss (MAE): 0.7338, validation MSE: 0.6513
# 2025-06-19 11:31:35 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 11:31:35 [INFO]: Saved the model to ./brits_model\20250619_T112345\BRITS.pypots
# 2025-06-19 11:31:35 [INFO]: Using the given device: cpu
# 2025-06-19 11:31:35 [INFO]: Model files will be saved to ./brits_model\20250619_T113135
# 2025-06-19 11:31:35 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T113135\tensorboard
# 2025-06-19 11:31:35 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 11:31:35 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 11:31:35 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 117,664
# Training model for missing rate 0.6 in cluster 0...
# 2025-06-19 11:32:03 [INFO]: Epoch 001 - training loss (MAE): 1.5189, validation MSE: 1.2884
# 2025-06-19 11:32:19 [INFO]: Epoch 002 - training loss (MAE): 1.4259, validation MSE: 1.1388
# 2025-06-19 11:32:35 [INFO]: Epoch 003 - training loss (MAE): 1.3427, validation MSE: 1.0130
# 2025-06-19 11:32:52 [INFO]: Epoch 004 - training loss (MAE): 1.2621, validation MSE: 0.9121
# 2025-06-19 11:33:08 [INFO]: Epoch 005 - training loss (MAE): 1.1901, validation MSE: 0.8403
# 2025-06-19 11:33:25 [INFO]: Epoch 006 - training loss (MAE): 1.1355, validation MSE: 0.7963
# 2025-06-19 11:33:42 [INFO]: Epoch 007 - training loss (MAE): 1.0911, validation MSE: 0.7677
# 2025-06-19 11:33:59 [INFO]: Epoch 008 - training loss (MAE): 1.0553, validation MSE: 0.7470
# 2025-06-19 11:34:15 [INFO]: Epoch 009 - training loss (MAE): 1.0267, validation MSE: 0.7317
# 2025-06-19 11:34:32 [INFO]: Epoch 010 - training loss (MAE): 0.9982, validation MSE: 0.7190
# 2025-06-19 11:34:48 [INFO]: Epoch 011 - training loss (MAE): 0.9732, validation MSE: 0.7051
# 2025-06-19 11:35:05 [INFO]: Epoch 012 - training loss (MAE): 0.9530, validation MSE: 0.6931
# 2025-06-19 11:35:25 [INFO]: Epoch 013 - training loss (MAE): 0.9338, validation MSE: 0.6780
# 2025-06-19 11:35:46 [INFO]: Epoch 014 - training loss (MAE): 0.9141, validation MSE: 0.6609
# 2025-06-19 11:36:07 [INFO]: Epoch 015 - training loss (MAE): 0.8994, validation MSE: 0.6438
# 2025-06-19 11:36:27 [INFO]: Epoch 016 - training loss (MAE): 0.8819, validation MSE: 0.6251
# 2025-06-19 11:36:47 [INFO]: Epoch 017 - training loss (MAE): 0.8684, validation MSE: 0.6086
# 2025-06-19 11:37:07 [INFO]: Epoch 018 - training loss (MAE): 0.8528, validation MSE: 0.5934
# 2025-06-19 11:37:27 [INFO]: Epoch 019 - training loss (MAE): 0.8390, validation MSE: 0.5789
# 2025-06-19 11:37:46 [INFO]: Epoch 020 - training loss (MAE): 0.8278, validation MSE: 0.5663
# 2025-06-19 11:38:05 [INFO]: Epoch 021 - training loss (MAE): 0.8135, validation MSE: 0.5552
# 2025-06-19 11:38:24 [INFO]: Epoch 022 - training loss (MAE): 0.8032, validation MSE: 0.5442
# 2025-06-19 11:38:43 [INFO]: Epoch 023 - training loss (MAE): 0.7922, validation MSE: 0.5346
# 2025-06-19 11:39:04 [INFO]: Epoch 024 - training loss (MAE): 0.7824, validation MSE: 0.5256
# 2025-06-19 11:39:22 [INFO]: Epoch 025 - training loss (MAE): 0.7718, validation MSE: 0.5171
# 2025-06-19 11:39:22 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 11:39:22 [INFO]: Saved the model to ./brits_model\20250619_T113135\BRITS.pypots
# 2025-06-19 11:39:22 [INFO]: Using the given device: cpu
# 2025-06-19 11:39:22 [INFO]: Model files will be saved to ./brits_model\20250619_T113922
# 2025-06-19 11:39:22 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T113922\tensorboard
# 2025-06-19 11:39:22 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 11:39:22 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 11:39:22 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 117,664
# Training model for missing rate 0.99 in cluster 0...
# 2025-06-19 11:39:51 [INFO]: Epoch 001 - training loss (MAE): 1.5257, validation MSE: 1.5318
# 2025-06-19 11:40:13 [INFO]: Epoch 002 - training loss (MAE): 1.4467, validation MSE: 1.5050
# 2025-06-19 11:40:34 [INFO]: Epoch 003 - training loss (MAE): 1.3665, validation MSE: 1.4809
# 2025-06-19 11:40:56 [INFO]: Epoch 004 - training loss (MAE): 1.2833, validation MSE: 1.4579
# 2025-06-19 11:41:17 [INFO]: Epoch 005 - training loss (MAE): 1.2158, validation MSE: 1.4342
# 2025-06-19 11:41:38 [INFO]: Epoch 006 - training loss (MAE): 1.1588, validation MSE: 1.4080
# 2025-06-19 11:41:58 [INFO]: Epoch 007 - training loss (MAE): 1.1133, validation MSE: 1.3768
# 2025-06-19 11:42:21 [INFO]: Epoch 008 - training loss (MAE): 1.0732, validation MSE: 1.3413
# 2025-06-19 11:42:42 [INFO]: Epoch 009 - training loss (MAE): 1.0360, validation MSE: 1.3037
# 2025-06-19 11:43:02 [INFO]: Epoch 010 - training loss (MAE): 1.0019, validation MSE: 1.2675
# 2025-06-19 11:43:22 [INFO]: Epoch 011 - training loss (MAE): 0.9721, validation MSE: 1.2342
# 2025-06-19 11:43:42 [INFO]: Epoch 012 - training loss (MAE): 0.9439, validation MSE: 1.2006
# 2025-06-19 11:44:02 [INFO]: Epoch 013 - training loss (MAE): 0.9165, validation MSE: 1.1670
# 2025-06-19 11:44:22 [INFO]: Epoch 014 - training loss (MAE): 0.8908, validation MSE: 1.1419
# 2025-06-19 11:44:42 [INFO]: Epoch 015 - training loss (MAE): 0.8672, validation MSE: 1.1218
# 2025-06-19 11:45:01 [INFO]: Epoch 016 - training loss (MAE): 0.8453, validation MSE: 1.1057
# 2025-06-19 11:45:21 [INFO]: Epoch 017 - training loss (MAE): 0.8259, validation MSE: 1.0920
# 2025-06-19 11:45:40 [INFO]: Epoch 018 - training loss (MAE): 0.8095, validation MSE: 1.0790
# 2025-06-19 11:46:00 [INFO]: Epoch 019 - training loss (MAE): 0.7920, validation MSE: 1.0675
# 2025-06-19 11:46:21 [INFO]: Epoch 020 - training loss (MAE): 0.7771, validation MSE: 1.0564
# 2025-06-19 11:46:40 [INFO]: Epoch 021 - training loss (MAE): 0.7638, validation MSE: 1.0444
# 2025-06-19 11:46:59 [INFO]: Epoch 022 - training loss (MAE): 0.7504, validation MSE: 1.0299
# 2025-06-19 11:47:19 [INFO]: Epoch 023 - training loss (MAE): 0.7381, validation MSE: 1.0166
# 2025-06-19 11:47:39 [INFO]: Epoch 024 - training loss (MAE): 0.7242, validation MSE: 1.0036
# 2025-06-19 11:47:57 [INFO]: Epoch 025 - training loss (MAE): 0.7131, validation MSE: 0.9904
# 2025-06-19 11:47:57 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 11:47:58 [INFO]: Saved the model to ./brits_model\20250619_T113922\BRITS.pypots
# 2025-06-19 11:47:58 [INFO]: Using the given device: cpu
# 2025-06-19 11:47:58 [INFO]: Model files will be saved to ./brits_model\20250619_T114758
# 2025-06-19 11:47:58 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T114758\tensorboard
# 2025-06-19 11:47:58 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 11:47:58 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 11:47:58 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 58,304
# Training BRITS models for cluster 1...
# Training model for missing rate 0.05 in cluster 1...
# 2025-06-19 11:48:23 [INFO]: Epoch 001 - training loss (MAE): 1.4295, validation MSE: 2.3160
# 2025-06-19 11:48:41 [INFO]: Epoch 002 - training loss (MAE): 1.3395, validation MSE: 2.0120
# 2025-06-19 11:48:57 [INFO]: Epoch 003 - training loss (MAE): 1.2649, validation MSE: 1.7535
# 2025-06-19 11:49:14 [INFO]: Epoch 004 - training loss (MAE): 1.1905, validation MSE: 1.5296
# 2025-06-19 11:49:31 [INFO]: Epoch 005 - training loss (MAE): 1.1340, validation MSE: 1.3454
# 2025-06-19 11:49:47 [INFO]: Epoch 006 - training loss (MAE): 1.0832, validation MSE: 1.1986
# 2025-06-19 11:50:04 [INFO]: Epoch 007 - training loss (MAE): 1.0424, validation MSE: 1.0864
# 2025-06-19 11:50:21 [INFO]: Epoch 008 - training loss (MAE): 1.0070, validation MSE: 1.0040
# 2025-06-19 11:50:38 [INFO]: Epoch 009 - training loss (MAE): 0.9740, validation MSE: 0.9400
# 2025-06-19 11:50:55 [INFO]: Epoch 010 - training loss (MAE): 0.9517, validation MSE: 0.8991
# 2025-06-19 11:51:11 [INFO]: Epoch 011 - training loss (MAE): 0.9288, validation MSE: 0.8670
# 2025-06-19 11:51:28 [INFO]: Epoch 012 - training loss (MAE): 0.9078, validation MSE: 0.8394
# 2025-06-19 11:51:48 [INFO]: Epoch 013 - training loss (MAE): 0.8883, validation MSE: 0.8126
# 2025-06-19 11:52:07 [INFO]: Epoch 014 - training loss (MAE): 0.8740, validation MSE: 0.7861
# 2025-06-19 11:52:25 [INFO]: Epoch 015 - training loss (MAE): 0.8589, validation MSE: 0.7512
# 2025-06-19 11:52:42 [INFO]: Epoch 016 - training loss (MAE): 0.8460, validation MSE: 0.7210
# 2025-06-19 11:53:00 [INFO]: Epoch 017 - training loss (MAE): 0.8327, validation MSE: 0.6856
# 2025-06-19 11:53:19 [INFO]: Epoch 018 - training loss (MAE): 0.8219, validation MSE: 0.6536
# 2025-06-19 11:53:36 [INFO]: Epoch 019 - training loss (MAE): 0.8099, validation MSE: 0.6280
# 2025-06-19 11:53:54 [INFO]: Epoch 020 - training loss (MAE): 0.8001, validation MSE: 0.6045
# 2025-06-19 11:54:11 [INFO]: Epoch 021 - training loss (MAE): 0.7914, validation MSE: 0.5828
# 2025-06-19 11:54:29 [INFO]: Epoch 022 - training loss (MAE): 0.7809, validation MSE: 0.5593
# 2025-06-19 11:54:48 [INFO]: Epoch 023 - training loss (MAE): 0.7734, validation MSE: 0.5366
# 2025-06-19 11:55:05 [INFO]: Epoch 024 - training loss (MAE): 0.7644, validation MSE: 0.5153
# 2025-06-19 11:55:22 [INFO]: Epoch 025 - training loss (MAE): 0.7566, validation MSE: 0.4974
# 2025-06-19 11:55:22 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 11:55:22 [INFO]: Saved the model to ./brits_model\20250619_T114758\BRITS.pypots
# 2025-06-19 11:55:22 [INFO]: Using the given device: cpu
# 2025-06-19 11:55:22 [INFO]: Model files will be saved to ./brits_model\20250619_T115522
# 2025-06-19 11:55:22 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T115522\tensorboard
# 2025-06-19 11:55:22 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 11:55:22 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 11:55:22 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 58,304
# Training model for missing rate 0.2 in cluster 1...
# 2025-06-19 11:55:47 [INFO]: Epoch 001 - training loss (MAE): 1.3879, validation MSE: 2.1053
# 2025-06-19 11:56:03 [INFO]: Epoch 002 - training loss (MAE): 1.3134, validation MSE: 1.9156
# 2025-06-19 11:56:20 [INFO]: Epoch 003 - training loss (MAE): 1.2428, validation MSE: 1.7503
# 2025-06-19 11:56:37 [INFO]: Epoch 004 - training loss (MAE): 1.1774, validation MSE: 1.6049
# 2025-06-19 11:56:53 [INFO]: Epoch 005 - training loss (MAE): 1.1213, validation MSE: 1.4751
# 2025-06-19 11:57:10 [INFO]: Epoch 006 - training loss (MAE): 1.0703, validation MSE: 1.3576
# 2025-06-19 11:57:27 [INFO]: Epoch 007 - training loss (MAE): 1.0268, validation MSE: 1.2519
# 2025-06-19 11:57:43 [INFO]: Epoch 008 - training loss (MAE): 0.9902, validation MSE: 1.1588
# 2025-06-19 11:58:00 [INFO]: Epoch 009 - training loss (MAE): 0.9644, validation MSE: 1.0850
# 2025-06-19 11:58:17 [INFO]: Epoch 010 - training loss (MAE): 0.9378, validation MSE: 1.0263
# 2025-06-19 11:58:33 [INFO]: Epoch 011 - training loss (MAE): 0.9188, validation MSE: 0.9773
# 2025-06-19 11:58:50 [INFO]: Epoch 012 - training loss (MAE): 0.8993, validation MSE: 0.9395
# 2025-06-19 11:59:07 [INFO]: Epoch 013 - training loss (MAE): 0.8816, validation MSE: 0.9026
# 2025-06-19 11:59:24 [INFO]: Epoch 014 - training loss (MAE): 0.8686, validation MSE: 0.8729
# 2025-06-19 11:59:41 [INFO]: Epoch 015 - training loss (MAE): 0.8507, validation MSE: 0.8478
# 2025-06-19 11:59:58 [INFO]: Epoch 016 - training loss (MAE): 0.8393, validation MSE: 0.8258
# 2025-06-19 12:00:15 [INFO]: Epoch 017 - training loss (MAE): 0.8282, validation MSE: 0.8063
# 2025-06-19 12:00:32 [INFO]: Epoch 018 - training loss (MAE): 0.8155, validation MSE: 0.7853
# 2025-06-19 12:00:48 [INFO]: Epoch 019 - training loss (MAE): 0.8032, validation MSE: 0.7632
# 2025-06-19 12:01:05 [INFO]: Epoch 020 - training loss (MAE): 0.7953, validation MSE: 0.7432
# 2025-06-19 12:01:22 [INFO]: Epoch 021 - training loss (MAE): 0.7843, validation MSE: 0.7229
# 2025-06-19 12:01:39 [INFO]: Epoch 022 - training loss (MAE): 0.7745, validation MSE: 0.7023
# 2025-06-19 12:01:55 [INFO]: Epoch 023 - training loss (MAE): 0.7638, validation MSE: 0.6797
# 2025-06-19 12:02:12 [INFO]: Epoch 024 - training loss (MAE): 0.7567, validation MSE: 0.6594
# 2025-06-19 12:02:29 [INFO]: Epoch 025 - training loss (MAE): 0.7473, validation MSE: 0.6377
# 2025-06-19 12:02:29 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 12:02:29 [INFO]: Saved the model to ./brits_model\20250619_T115522\BRITS.pypots
# 2025-06-19 12:02:29 [INFO]: Using the given device: cpu
# 2025-06-19 12:02:29 [INFO]: Model files will be saved to ./brits_model\20250619_T120229
# 2025-06-19 12:02:29 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T120229\tensorboard
# 2025-06-19 12:02:29 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 12:02:29 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 12:02:29 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 58,304
# Training model for missing rate 0.6 in cluster 1...
# 2025-06-19 12:02:56 [INFO]: Epoch 001 - training loss (MAE): 1.3898, validation MSE: 1.5321
# 2025-06-19 12:03:13 [INFO]: Epoch 002 - training loss (MAE): 1.3254, validation MSE: 1.4264
# 2025-06-19 12:03:30 [INFO]: Epoch 003 - training loss (MAE): 1.2610, validation MSE: 1.3341
# 2025-06-19 12:03:48 [INFO]: Epoch 004 - training loss (MAE): 1.2043, validation MSE: 1.2585
# 2025-06-19 12:04:06 [INFO]: Epoch 005 - training loss (MAE): 1.1446, validation MSE: 1.1976
# 2025-06-19 12:04:23 [INFO]: Epoch 006 - training loss (MAE): 1.0915, validation MSE: 1.1483
# 2025-06-19 12:04:41 [INFO]: Epoch 007 - training loss (MAE): 1.0468, validation MSE: 1.1063
# 2025-06-19 12:05:00 [INFO]: Epoch 008 - training loss (MAE): 1.0118, validation MSE: 1.0701
# 2025-06-19 12:05:17 [INFO]: Epoch 009 - training loss (MAE): 0.9845, validation MSE: 1.0378
# 2025-06-19 12:05:35 [INFO]: Epoch 010 - training loss (MAE): 0.9594, validation MSE: 1.0071
# 2025-06-19 12:05:52 [INFO]: Epoch 011 - training loss (MAE): 0.9357, validation MSE: 0.9786
# 2025-06-19 12:06:10 [INFO]: Epoch 012 - training loss (MAE): 0.9145, validation MSE: 0.9515
# 2025-06-19 12:06:28 [INFO]: Epoch 013 - training loss (MAE): 0.8978, validation MSE: 0.9252
# 2025-06-19 12:06:45 [INFO]: Epoch 014 - training loss (MAE): 0.8789, validation MSE: 0.8982
# 2025-06-19 12:07:03 [INFO]: Epoch 015 - training loss (MAE): 0.8645, validation MSE: 0.8719
# 2025-06-19 12:07:20 [INFO]: Epoch 016 - training loss (MAE): 0.8505, validation MSE: 0.8504
# 2025-06-19 12:07:37 [INFO]: Epoch 017 - training loss (MAE): 0.8377, validation MSE: 0.8320
# 2025-06-19 12:07:55 [INFO]: Epoch 018 - training loss (MAE): 0.8241, validation MSE: 0.8166
# 2025-06-19 12:08:13 [INFO]: Epoch 019 - training loss (MAE): 0.8108, validation MSE: 0.8012
# 2025-06-19 12:08:32 [INFO]: Epoch 020 - training loss (MAE): 0.8018, validation MSE: 0.7890
# 2025-06-19 12:08:51 [INFO]: Epoch 021 - training loss (MAE): 0.7909, validation MSE: 0.7788
# 2025-06-19 12:09:10 [INFO]: Epoch 022 - training loss (MAE): 0.7803, validation MSE: 0.7668
# 2025-06-19 12:09:27 [INFO]: Epoch 023 - training loss (MAE): 0.7688, validation MSE: 0.7538
# 2025-06-19 12:09:45 [INFO]: Epoch 024 - training loss (MAE): 0.7591, validation MSE: 0.7427
# 2025-06-19 12:10:02 [INFO]: Epoch 025 - training loss (MAE): 0.7481, validation MSE: 0.7312
# 2025-06-19 12:10:02 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 12:10:02 [INFO]: Saved the model to ./brits_model\20250619_T120229\BRITS.pypots
# 2025-06-19 12:10:02 [INFO]: Using the given device: cpu
# 2025-06-19 12:10:02 [INFO]: Model files will be saved to ./brits_model\20250619_T121002
# 2025-06-19 12:10:02 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T121002\tensorboard
# 2025-06-19 12:10:02 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 12:10:02 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 12:10:02 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 58,304
# Training model for missing rate 0.99 in cluster 1...
# 2025-06-19 12:10:28 [INFO]: Epoch 001 - training loss (MAE): 1.4059, validation MSE: 1.6929
# 2025-06-19 12:10:46 [INFO]: Epoch 002 - training loss (MAE): 1.3504, validation MSE: 1.6635
# 2025-06-19 12:11:06 [INFO]: Epoch 003 - training loss (MAE): 1.3059, validation MSE: 1.6370
# 2025-06-19 12:11:25 [INFO]: Epoch 004 - training loss (MAE): 1.2569, validation MSE: 1.6127
# 2025-06-19 12:11:43 [INFO]: Epoch 005 - training loss (MAE): 1.2034, validation MSE: 1.5907
# 2025-06-19 12:12:02 [INFO]: Epoch 006 - training loss (MAE): 1.1581, validation MSE: 1.5691
# 2025-06-19 12:12:20 [INFO]: Epoch 007 - training loss (MAE): 1.1157, validation MSE: 1.5476
# 2025-06-19 12:12:39 [INFO]: Epoch 008 - training loss (MAE): 1.0818, validation MSE: 1.5250
# 2025-06-19 12:12:57 [INFO]: Epoch 009 - training loss (MAE): 1.0537, validation MSE: 1.4999
# 2025-06-19 12:13:16 [INFO]: Epoch 010 - training loss (MAE): 1.0177, validation MSE: 1.4725
# 2025-06-19 12:13:36 [INFO]: Epoch 011 - training loss (MAE): 0.9930, validation MSE: 1.4431
# 2025-06-19 12:13:55 [INFO]: Epoch 012 - training loss (MAE): 0.9661, validation MSE: 1.4138
# 2025-06-19 12:14:14 [INFO]: Epoch 013 - training loss (MAE): 0.9412, validation MSE: 1.3857
# 2025-06-19 12:14:34 [INFO]: Epoch 014 - training loss (MAE): 0.9192, validation MSE: 1.3569
# 2025-06-19 12:14:54 [INFO]: Epoch 015 - training loss (MAE): 0.8964, validation MSE: 1.3271
# 2025-06-19 12:15:12 [INFO]: Epoch 016 - training loss (MAE): 0.8809, validation MSE: 1.2939
# 2025-06-19 12:15:31 [INFO]: Epoch 017 - training loss (MAE): 0.8571, validation MSE: 1.2659
# 2025-06-19 12:15:48 [INFO]: Epoch 018 - training loss (MAE): 0.8371, validation MSE: 1.2413
# 2025-06-19 12:16:05 [INFO]: Epoch 019 - training loss (MAE): 0.8212, validation MSE: 1.2208
# 2025-06-19 12:16:23 [INFO]: Epoch 020 - training loss (MAE): 0.8079, validation MSE: 1.2043
# 2025-06-19 12:16:40 [INFO]: Epoch 021 - training loss (MAE): 0.7951, validation MSE: 1.1897
# 2025-06-19 12:16:58 [INFO]: Epoch 022 - training loss (MAE): 0.7819, validation MSE: 1.1771
# 2025-06-19 12:17:15 [INFO]: Epoch 023 - training loss (MAE): 0.7664, validation MSE: 1.1657
# 2025-06-19 12:17:33 [INFO]: Epoch 024 - training loss (MAE): 0.7558, validation MSE: 1.1556
# 2025-06-19 12:17:50 [INFO]: Epoch 025 - training loss (MAE): 0.7415, validation MSE: 1.1476
# 2025-06-19 12:17:50 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 12:17:50 [INFO]: Saved the model to ./brits_model\20250619_T121002\BRITS.pypots
# 2025-06-19 12:17:50 [INFO]: Using the given device: cpu
# 2025-06-19 12:17:50 [INFO]: Model files will be saved to ./brits_model\20250619_T121750
# 2025-06-19 12:17:50 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T121750\tensorboard
# 2025-06-19 12:17:50 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 12:17:50 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 12:17:50 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 59,728
# Training BRITS models for cluster 2...
# Training model for missing rate 0.05 in cluster 2...
# 2025-06-19 12:18:16 [INFO]: Epoch 001 - training loss (MAE): 1.3307, validation MSE: 3.7365
# 2025-06-19 12:18:33 [INFO]: Epoch 002 - training loss (MAE): 1.2558, validation MSE: 3.2913
# 2025-06-19 12:18:51 [INFO]: Epoch 003 - training loss (MAE): 1.1834, validation MSE: 2.9015
# 2025-06-19 12:19:07 [INFO]: Epoch 004 - training loss (MAE): 1.1228, validation MSE: 2.5883
# 2025-06-19 12:19:25 [INFO]: Epoch 005 - training loss (MAE): 1.0648, validation MSE: 2.3235
# 2025-06-19 12:19:43 [INFO]: Epoch 006 - training loss (MAE): 1.0156, validation MSE: 2.0966
# 2025-06-19 12:20:02 [INFO]: Epoch 007 - training loss (MAE): 0.9749, validation MSE: 1.8998
# 2025-06-19 12:20:20 [INFO]: Epoch 008 - training loss (MAE): 0.9366, validation MSE: 1.7302
# 2025-06-19 12:20:38 [INFO]: Epoch 009 - training loss (MAE): 0.9073, validation MSE: 1.5850
# 2025-06-19 12:20:57 [INFO]: Epoch 010 - training loss (MAE): 0.8808, validation MSE: 1.4623
# 2025-06-19 12:21:15 [INFO]: Epoch 011 - training loss (MAE): 0.8566, validation MSE: 1.3648
# 2025-06-19 12:21:34 [INFO]: Epoch 012 - training loss (MAE): 0.8379, validation MSE: 1.2844
# 2025-06-19 12:21:53 [INFO]: Epoch 013 - training loss (MAE): 0.8234, validation MSE: 1.2237
# 2025-06-19 12:22:12 [INFO]: Epoch 014 - training loss (MAE): 0.8091, validation MSE: 1.1606
# 2025-06-19 12:22:29 [INFO]: Epoch 015 - training loss (MAE): 0.7963, validation MSE: 1.1084
# 2025-06-19 12:22:46 [INFO]: Epoch 016 - training loss (MAE): 0.7842, validation MSE: 1.0548
# 2025-06-19 12:23:05 [INFO]: Epoch 017 - training loss (MAE): 0.7697, validation MSE: 0.9992
# 2025-06-19 12:23:23 [INFO]: Epoch 018 - training loss (MAE): 0.7629, validation MSE: 0.9591
# 2025-06-19 12:23:40 [INFO]: Epoch 019 - training loss (MAE): 0.7480, validation MSE: 0.9148
# 2025-06-19 12:23:57 [INFO]: Epoch 020 - training loss (MAE): 0.7418, validation MSE: 0.8760
# 2025-06-19 12:24:13 [INFO]: Epoch 021 - training loss (MAE): 0.7305, validation MSE: 0.8340
# 2025-06-19 12:24:29 [INFO]: Epoch 022 - training loss (MAE): 0.7191, validation MSE: 0.7900
# 2025-06-19 12:24:45 [INFO]: Epoch 023 - training loss (MAE): 0.7096, validation MSE: 0.7544
# 2025-06-19 12:25:01 [INFO]: Epoch 024 - training loss (MAE): 0.7033, validation MSE: 0.7224
# 2025-06-19 12:25:17 [INFO]: Epoch 025 - training loss (MAE): 0.6940, validation MSE: 0.6840
# 2025-06-19 12:25:17 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 12:25:17 [INFO]: Saved the model to ./brits_model\20250619_T121750\BRITS.pypots
# 2025-06-19 12:25:17 [INFO]: Using the given device: cpu
# 2025-06-19 12:25:17 [INFO]: Model files will be saved to ./brits_model\20250619_T122517
# 2025-06-19 12:25:17 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T122517\tensorboard
# 2025-06-19 12:25:17 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 12:25:17 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 12:25:17 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 59,728
# Training model for missing rate 0.2 in cluster 2...
# 2025-06-19 12:25:41 [INFO]: Epoch 001 - training loss (MAE): 1.2964, validation MSE: 2.9692
# 2025-06-19 12:25:57 [INFO]: Epoch 002 - training loss (MAE): 1.2190, validation MSE: 2.6950
# 2025-06-19 12:26:14 [INFO]: Epoch 003 - training loss (MAE): 1.1554, validation MSE: 2.4680
# 2025-06-19 12:26:30 [INFO]: Epoch 004 - training loss (MAE): 1.0961, validation MSE: 2.2773
# 2025-06-19 12:26:46 [INFO]: Epoch 005 - training loss (MAE): 1.0446, validation MSE: 2.1195
# 2025-06-19 12:27:03 [INFO]: Epoch 006 - training loss (MAE): 0.9995, validation MSE: 1.9935
# 2025-06-19 12:27:21 [INFO]: Epoch 007 - training loss (MAE): 0.9596, validation MSE: 1.8846
# 2025-06-19 12:27:36 [INFO]: Epoch 008 - training loss (MAE): 0.9254, validation MSE: 1.7936
# 2025-06-19 12:27:52 [INFO]: Epoch 009 - training loss (MAE): 0.8972, validation MSE: 1.7200
# 2025-06-19 12:28:07 [INFO]: Epoch 010 - training loss (MAE): 0.8709, validation MSE: 1.6542
# 2025-06-19 12:28:23 [INFO]: Epoch 011 - training loss (MAE): 0.8522, validation MSE: 1.5975
# 2025-06-19 12:28:37 [INFO]: Epoch 012 - training loss (MAE): 0.8344, validation MSE: 1.5390
# 2025-06-19 12:28:52 [INFO]: Epoch 013 - training loss (MAE): 0.8228, validation MSE: 1.4899
# 2025-06-19 12:29:06 [INFO]: Epoch 014 - training loss (MAE): 0.8064, validation MSE: 1.4387
# 2025-06-19 12:29:21 [INFO]: Epoch 015 - training loss (MAE): 0.7933, validation MSE: 1.3873
# 2025-06-19 12:29:36 [INFO]: Epoch 016 - training loss (MAE): 0.7796, validation MSE: 1.3364
# 2025-06-19 12:29:51 [INFO]: Epoch 017 - training loss (MAE): 0.7714, validation MSE: 1.2902
# 2025-06-19 12:30:06 [INFO]: Epoch 018 - training loss (MAE): 0.7614, validation MSE: 1.2398
# 2025-06-19 12:30:20 [INFO]: Epoch 019 - training loss (MAE): 0.7499, validation MSE: 1.1902
# 2025-06-19 12:30:35 [INFO]: Epoch 020 - training loss (MAE): 0.7390, validation MSE: 1.1426
# 2025-06-19 12:30:49 [INFO]: Epoch 021 - training loss (MAE): 0.7299, validation MSE: 1.0941
# 2025-06-19 12:31:03 [INFO]: Epoch 022 - training loss (MAE): 0.7199, validation MSE: 1.0493
# 2025-06-19 12:31:17 [INFO]: Epoch 023 - training loss (MAE): 0.7103, validation MSE: 1.0066
# 2025-06-19 12:31:32 [INFO]: Epoch 024 - training loss (MAE): 0.7026, validation MSE: 0.9710
# 2025-06-19 12:31:47 [INFO]: Epoch 025 - training loss (MAE): 0.6932, validation MSE: 0.9360
# 2025-06-19 12:31:47 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 12:31:47 [INFO]: Saved the model to ./brits_model\20250619_T122517\BRITS.pypots
# 2025-06-19 12:31:47 [INFO]: Using the given device: cpu
# 2025-06-19 12:31:47 [INFO]: Model files will be saved to ./brits_model\20250619_T123147
# 2025-06-19 12:31:47 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T123147\tensorboard
# 2025-06-19 12:31:47 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 12:31:47 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 12:31:47 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 59,728
# Training model for missing rate 0.6 in cluster 2...
# 2025-06-19 12:32:09 [INFO]: Epoch 001 - training loss (MAE): 1.3321, validation MSE: 1.6882
# 2025-06-19 12:32:23 [INFO]: Epoch 002 - training loss (MAE): 1.2732, validation MSE: 1.5813
# 2025-06-19 12:32:38 [INFO]: Epoch 003 - training loss (MAE): 1.2051, validation MSE: 1.4866
# 2025-06-19 12:32:53 [INFO]: Epoch 004 - training loss (MAE): 1.1390, validation MSE: 1.4054
# 2025-06-19 12:33:07 [INFO]: Epoch 005 - training loss (MAE): 1.0835, validation MSE: 1.3355
# 2025-06-19 12:33:23 [INFO]: Epoch 006 - training loss (MAE): 1.0298, validation MSE: 1.2727
# 2025-06-19 12:33:38 [INFO]: Epoch 007 - training loss (MAE): 0.9885, validation MSE: 1.2160
# 2025-06-19 12:33:53 [INFO]: Epoch 008 - training loss (MAE): 0.9560, validation MSE: 1.1649
# 2025-06-19 12:34:07 [INFO]: Epoch 009 - training loss (MAE): 0.9223, validation MSE: 1.1178
# 2025-06-19 12:34:22 [INFO]: Epoch 010 - training loss (MAE): 0.9005, validation MSE: 1.0792
# 2025-06-19 12:34:36 [INFO]: Epoch 011 - training loss (MAE): 0.8779, validation MSE: 1.0472
# 2025-06-19 12:34:51 [INFO]: Epoch 012 - training loss (MAE): 0.8607, validation MSE: 1.0200
# 2025-06-19 12:35:06 [INFO]: Epoch 013 - training loss (MAE): 0.8435, validation MSE: 0.9945
# 2025-06-19 12:35:20 [INFO]: Epoch 014 - training loss (MAE): 0.8304, validation MSE: 0.9695
# 2025-06-19 12:35:35 [INFO]: Epoch 015 - training loss (MAE): 0.8167, validation MSE: 0.9447
# 2025-06-19 12:35:50 [INFO]: Epoch 016 - training loss (MAE): 0.8052, validation MSE: 0.9202
# 2025-06-19 12:36:05 [INFO]: Epoch 017 - training loss (MAE): 0.7925, validation MSE: 0.8946
# 2025-06-19 12:36:21 [INFO]: Epoch 018 - training loss (MAE): 0.7818, validation MSE: 0.8703
# 2025-06-19 12:36:38 [INFO]: Epoch 019 - training loss (MAE): 0.7689, validation MSE: 0.8466
# 2025-06-19 12:36:54 [INFO]: Epoch 020 - training loss (MAE): 0.7610, validation MSE: 0.8286
# 2025-06-19 12:37:09 [INFO]: Epoch 021 - training loss (MAE): 0.7490, validation MSE: 0.8128
# 2025-06-19 12:37:24 [INFO]: Epoch 022 - training loss (MAE): 0.7400, validation MSE: 0.8000
# 2025-06-19 12:37:39 [INFO]: Epoch 023 - training loss (MAE): 0.7306, validation MSE: 0.7886
# 2025-06-19 12:37:55 [INFO]: Epoch 024 - training loss (MAE): 0.7204, validation MSE: 0.7759
# 2025-06-19 12:38:11 [INFO]: Epoch 025 - training loss (MAE): 0.7124, validation MSE: 0.7626
# 2025-06-19 12:38:11 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 12:38:11 [INFO]: Saved the model to ./brits_model\20250619_T123147\BRITS.pypots
# 2025-06-19 12:38:11 [INFO]: Using the given device: cpu
# 2025-06-19 12:38:11 [INFO]: Model files will be saved to ./brits_model\20250619_T123811
# 2025-06-19 12:38:11 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T123811\tensorboard
# 2025-06-19 12:38:11 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 12:38:11 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 12:38:11 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 59,728
# Training model for missing rate 0.99 in cluster 2...
# 2025-06-19 12:38:34 [INFO]: Epoch 001 - training loss (MAE): 1.2862, validation MSE: 1.5545
# 2025-06-19 12:38:50 [INFO]: Epoch 002 - training loss (MAE): 1.2349, validation MSE: 1.5294
# 2025-06-19 12:39:06 [INFO]: Epoch 003 - training loss (MAE): 1.1795, validation MSE: 1.5043
# 2025-06-19 12:39:23 [INFO]: Epoch 004 - training loss (MAE): 1.1259, validation MSE: 1.4805
# 2025-06-19 12:39:39 [INFO]: Epoch 005 - training loss (MAE): 1.0695, validation MSE: 1.4576
# 2025-06-19 12:39:54 [INFO]: Epoch 006 - training loss (MAE): 1.0319, validation MSE: 1.4373
# 2025-06-19 12:40:11 [INFO]: Epoch 007 - training loss (MAE): 0.9900, validation MSE: 1.4181
# 2025-06-19 12:40:28 [INFO]: Epoch 008 - training loss (MAE): 0.9592, validation MSE: 1.3987
# 2025-06-19 12:40:43 [INFO]: Epoch 009 - training loss (MAE): 0.9270, validation MSE: 1.3774
# 2025-06-19 12:40:58 [INFO]: Epoch 010 - training loss (MAE): 0.8998, validation MSE: 1.3551
# 2025-06-19 12:41:14 [INFO]: Epoch 011 - training loss (MAE): 0.8813, validation MSE: 1.3310
# 2025-06-19 12:41:29 [INFO]: Epoch 012 - training loss (MAE): 0.8641, validation MSE: 1.3068
# 2025-06-19 12:41:45 [INFO]: Epoch 013 - training loss (MAE): 0.8442, validation MSE: 1.2821
# 2025-06-19 12:42:00 [INFO]: Epoch 014 - training loss (MAE): 0.8286, validation MSE: 1.2613
# 2025-06-19 12:42:16 [INFO]: Epoch 015 - training loss (MAE): 0.8141, validation MSE: 1.2428
# 2025-06-19 12:42:32 [INFO]: Epoch 016 - training loss (MAE): 0.8029, validation MSE: 1.2252
# 2025-06-19 12:42:48 [INFO]: Epoch 017 - training loss (MAE): 0.7872, validation MSE: 1.2061
# 2025-06-19 12:43:04 [INFO]: Epoch 018 - training loss (MAE): 0.7746, validation MSE: 1.1848
# 2025-06-19 12:43:20 [INFO]: Epoch 019 - training loss (MAE): 0.7617, validation MSE: 1.1584
# 2025-06-19 12:43:34 [INFO]: Epoch 020 - training loss (MAE): 0.7475, validation MSE: 1.1318
# 2025-06-19 12:43:49 [INFO]: Epoch 021 - training loss (MAE): 0.7352, validation MSE: 1.1102
# 2025-06-19 12:44:05 [INFO]: Epoch 022 - training loss (MAE): 0.7214, validation MSE: 1.0943
# 2025-06-19 12:44:27 [INFO]: Epoch 023 - training loss (MAE): 0.7103, validation MSE: 1.0819
# 2025-06-19 12:44:44 [INFO]: Epoch 024 - training loss (MAE): 0.6990, validation MSE: 1.0727
# 2025-06-19 12:45:01 [INFO]: Epoch 025 - training loss (MAE): 0.6864, validation MSE: 1.0613
# 2025-06-19 12:45:01 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 12:45:02 [INFO]: Saved the model to ./brits_model\20250619_T123811\BRITS.pypots
# 2025-06-19 12:45:02 [INFO]: Using the given device: cpu
# 2025-06-19 12:45:02 [INFO]: Model files will be saved to ./brits_model\20250619_T124502
# 2025-06-19 12:45:02 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T124502\tensorboard
# 2025-06-19 12:45:02 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 12:45:02 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 12:45:02 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 485,696
# Training BRITS models for cluster 3...
# Training model for missing rate 0.05 in cluster 3...
# 2025-06-19 12:45:35 [INFO]: Epoch 001 - training loss (MAE): 1.3472, validation MSE: 1.5163
# 2025-06-19 12:46:02 [INFO]: Epoch 002 - training loss (MAE): 1.1752, validation MSE: 1.0338
# 2025-06-19 12:46:26 [INFO]: Epoch 003 - training loss (MAE): 1.0932, validation MSE: 0.8282
# 2025-06-19 12:46:50 [INFO]: Epoch 004 - training loss (MAE): 1.0528, validation MSE: 0.7318
# 2025-06-19 12:47:13 [INFO]: Epoch 005 - training loss (MAE): 1.0187, validation MSE: 0.6549
# 2025-06-19 12:47:35 [INFO]: Epoch 006 - training loss (MAE): 0.9812, validation MSE: 0.6110
# 2025-06-19 12:47:57 [INFO]: Epoch 007 - training loss (MAE): 0.9474, validation MSE: 0.5759
# 2025-06-19 12:48:19 [INFO]: Epoch 008 - training loss (MAE): 0.9145, validation MSE: 0.5260
# 2025-06-19 12:48:42 [INFO]: Epoch 009 - training loss (MAE): 0.8844, validation MSE: 0.4726
# 2025-06-19 12:49:03 [INFO]: Epoch 010 - training loss (MAE): 0.8592, validation MSE: 0.4333
# 2025-06-19 12:49:27 [INFO]: Epoch 011 - training loss (MAE): 0.8396, validation MSE: 0.4114
# 2025-06-19 12:49:48 [INFO]: Epoch 012 - training loss (MAE): 0.8188, validation MSE: 0.3929
# 2025-06-19 12:50:11 [INFO]: Epoch 013 - training loss (MAE): 0.8013, validation MSE: 0.3798
# 2025-06-19 12:50:35 [INFO]: Epoch 014 - training loss (MAE): 0.7852, validation MSE: 0.3672
# 2025-06-19 12:50:59 [INFO]: Epoch 015 - training loss (MAE): 0.7718, validation MSE: 0.3569
# 2025-06-19 12:51:23 [INFO]: Epoch 016 - training loss (MAE): 0.7556, validation MSE: 0.3507
# 2025-06-19 12:51:47 [INFO]: Epoch 017 - training loss (MAE): 0.7469, validation MSE: 0.3455
# 2025-06-19 12:52:10 [INFO]: Epoch 018 - training loss (MAE): 0.7351, validation MSE: 0.3392
# 2025-06-19 12:52:33 [INFO]: Epoch 019 - training loss (MAE): 0.7232, validation MSE: 0.3321
# 2025-06-19 12:52:55 [INFO]: Epoch 020 - training loss (MAE): 0.7155, validation MSE: 0.3262
# 2025-06-19 12:53:19 [INFO]: Epoch 021 - training loss (MAE): 0.7044, validation MSE: 0.3225
# 2025-06-19 12:53:41 [INFO]: Epoch 022 - training loss (MAE): 0.6964, validation MSE: 0.3188
# 2025-06-19 12:54:05 [INFO]: Epoch 023 - training loss (MAE): 0.6876, validation MSE: 0.3124
# 2025-06-19 12:54:28 [INFO]: Epoch 024 - training loss (MAE): 0.6802, validation MSE: 0.3043
# 2025-06-19 12:54:51 [INFO]: Epoch 025 - training loss (MAE): 0.6722, validation MSE: 0.2964
# 2025-06-19 12:54:51 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 12:54:51 [INFO]: Saved the model to ./brits_model\20250619_T124502\BRITS.pypots
# 2025-06-19 12:54:51 [INFO]: Using the given device: cpu
# 2025-06-19 12:54:51 [INFO]: Model files will be saved to ./brits_model\20250619_T125451
# 2025-06-19 12:54:51 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T125451\tensorboard
# 2025-06-19 12:54:51 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 12:54:51 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 12:54:51 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 485,696
# Training model for missing rate 0.2 in cluster 3...
# 2025-06-19 12:55:19 [INFO]: Epoch 001 - training loss (MAE): 1.3306, validation MSE: 1.4156
# 2025-06-19 12:55:40 [INFO]: Epoch 002 - training loss (MAE): 1.1690, validation MSE: 1.1101
# 2025-06-19 12:56:01 [INFO]: Epoch 003 - training loss (MAE): 1.0790, validation MSE: 0.9564
# 2025-06-19 12:56:24 [INFO]: Epoch 004 - training loss (MAE): 1.0338, validation MSE: 0.8616
# 2025-06-19 12:56:49 [INFO]: Epoch 005 - training loss (MAE): 1.0014, validation MSE: 0.8113
# 2025-06-19 12:57:12 [INFO]: Epoch 006 - training loss (MAE): 0.9647, validation MSE: 0.7636
# 2025-06-19 12:57:37 [INFO]: Epoch 007 - training loss (MAE): 0.9290, validation MSE: 0.7162
# 2025-06-19 12:58:02 [INFO]: Epoch 008 - training loss (MAE): 0.8971, validation MSE: 0.6874
# 2025-06-19 12:58:28 [INFO]: Epoch 009 - training loss (MAE): 0.8684, validation MSE: 0.6673
# 2025-06-19 12:58:53 [INFO]: Epoch 010 - training loss (MAE): 0.8439, validation MSE: 0.6382
# 2025-06-19 12:59:18 [INFO]: Epoch 011 - training loss (MAE): 0.8254, validation MSE: 0.6177
# 2025-06-19 12:59:45 [INFO]: Epoch 012 - training loss (MAE): 0.8041, validation MSE: 0.6020
# 2025-06-19 13:00:12 [INFO]: Epoch 013 - training loss (MAE): 0.7865, validation MSE: 0.5931
# 2025-06-19 13:00:38 [INFO]: Epoch 014 - training loss (MAE): 0.7698, validation MSE: 0.5858
# 2025-06-19 13:01:06 [INFO]: Epoch 015 - training loss (MAE): 0.7573, validation MSE: 0.5818
# 2025-06-19 13:01:34 [INFO]: Epoch 016 - training loss (MAE): 0.7450, validation MSE: 0.5764
# 2025-06-19 13:02:00 [INFO]: Epoch 017 - training loss (MAE): 0.7317, validation MSE: 0.5684
# 2025-06-19 13:02:25 [INFO]: Epoch 018 - training loss (MAE): 0.7222, validation MSE: 0.5572
# 2025-06-19 13:02:51 [INFO]: Epoch 019 - training loss (MAE): 0.7111, validation MSE: 0.5474
# 2025-06-19 13:03:17 [INFO]: Epoch 020 - training loss (MAE): 0.7017, validation MSE: 0.5424
# 2025-06-19 13:03:43 [INFO]: Epoch 021 - training loss (MAE): 0.6948, validation MSE: 0.5361
# 2025-06-19 13:04:09 [INFO]: Epoch 022 - training loss (MAE): 0.6858, validation MSE: 0.5271
# 2025-06-19 13:04:33 [INFO]: Epoch 023 - training loss (MAE): 0.6777, validation MSE: 0.5195
# 2025-06-19 13:04:57 [INFO]: Epoch 024 - training loss (MAE): 0.6694, validation MSE: 0.5148
# 2025-06-19 13:05:20 [INFO]: Epoch 025 - training loss (MAE): 0.6637, validation MSE: 0.5090
# 2025-06-19 13:05:20 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 13:05:21 [INFO]: Saved the model to ./brits_model\20250619_T125451\BRITS.pypots
# 2025-06-19 13:05:21 [INFO]: Using the given device: cpu
# 2025-06-19 13:05:21 [INFO]: Model files will be saved to ./brits_model\20250619_T130521
# 2025-06-19 13:05:21 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T130521\tensorboard
# 2025-06-19 13:05:21 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 13:05:21 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 13:05:21 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 485,696
# Training model for missing rate 0.6 in cluster 3...
# 2025-06-19 13:05:53 [INFO]: Epoch 001 - training loss (MAE): 1.3543, validation MSE: 1.0204
# 2025-06-19 13:06:18 [INFO]: Epoch 002 - training loss (MAE): 1.2053, validation MSE: 0.8018
# 2025-06-19 13:06:43 [INFO]: Epoch 003 - training loss (MAE): 1.1004, validation MSE: 0.6765
# 2025-06-19 13:07:11 [INFO]: Epoch 004 - training loss (MAE): 1.0430, validation MSE: 0.6247
# 2025-06-19 13:07:37 [INFO]: Epoch 005 - training loss (MAE): 1.0138, validation MSE: 0.6034
# 2025-06-19 13:08:02 [INFO]: Epoch 006 - training loss (MAE): 0.9787, validation MSE: 0.5869
# 2025-06-19 13:08:29 [INFO]: Epoch 007 - training loss (MAE): 0.9488, validation MSE: 0.5782
# 2025-06-19 13:08:52 [INFO]: Epoch 008 - training loss (MAE): 0.9159, validation MSE: 0.5677
# 2025-06-19 13:09:16 [INFO]: Epoch 009 - training loss (MAE): 0.8858, validation MSE: 0.5568
# 2025-06-19 13:09:39 [INFO]: Epoch 010 - training loss (MAE): 0.8611, validation MSE: 0.5433
# 2025-06-19 13:10:03 [INFO]: Epoch 011 - training loss (MAE): 0.8406, validation MSE: 0.5304
# 2025-06-19 13:10:27 [INFO]: Epoch 012 - training loss (MAE): 0.8202, validation MSE: 0.5209
# 2025-06-19 13:10:50 [INFO]: Epoch 013 - training loss (MAE): 0.8057, validation MSE: 0.5170
# 2025-06-19 13:11:14 [INFO]: Epoch 014 - training loss (MAE): 0.7886, validation MSE: 0.5139
# 2025-06-19 13:11:40 [INFO]: Epoch 015 - training loss (MAE): 0.7749, validation MSE: 0.5133
# 2025-06-19 13:12:07 [INFO]: Epoch 016 - training loss (MAE): 0.7613, validation MSE: 0.5129
# 2025-06-19 13:12:32 [INFO]: Epoch 017 - training loss (MAE): 0.7486, validation MSE: 0.5115
# 2025-06-19 13:12:58 [INFO]: Epoch 018 - training loss (MAE): 0.7396, validation MSE: 0.5093
# 2025-06-19 13:13:24 [INFO]: Epoch 019 - training loss (MAE): 0.7295, validation MSE: 0.5060
# 2025-06-19 13:13:49 [INFO]: Epoch 020 - training loss (MAE): 0.7203, validation MSE: 0.5026
# 2025-06-19 13:14:14 [INFO]: Epoch 021 - training loss (MAE): 0.7124, validation MSE: 0.4981
# 2025-06-19 13:14:40 [INFO]: Epoch 022 - training loss (MAE): 0.7039, validation MSE: 0.4913
# 2025-06-19 13:15:06 [INFO]: Epoch 023 - training loss (MAE): 0.6940, validation MSE: 0.4843
# 2025-06-19 13:15:31 [INFO]: Epoch 024 - training loss (MAE): 0.6872, validation MSE: 0.4801
# 2025-06-19 13:15:56 [INFO]: Epoch 025 - training loss (MAE): 0.6803, validation MSE: 0.4763
# 2025-06-19 13:15:56 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 13:15:56 [INFO]: Saved the model to ./brits_model\20250619_T130521\BRITS.pypots
# 2025-06-19 13:15:56 [INFO]: Using the given device: cpu
# 2025-06-19 13:15:56 [INFO]: Model files will be saved to ./brits_model\20250619_T131556
# 2025-06-19 13:15:56 [INFO]: Tensorboard file will be saved to ./brits_model\20250619_T131556\tensorboard
# 2025-06-19 13:15:56 [INFO]: Using customized MAE as the training loss function.
# 2025-06-19 13:15:56 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-19 13:15:56 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 485,696
# Training model for missing rate 0.99 in cluster 3...
# 2025-06-19 13:16:32 [INFO]: Epoch 001 - training loss (MAE): 1.3217, validation MSE: 1.5456
# 2025-06-19 13:17:00 [INFO]: Epoch 002 - training loss (MAE): 1.1810, validation MSE: 1.4740
# 2025-06-19 13:17:28 [INFO]: Epoch 003 - training loss (MAE): 1.0762, validation MSE: 1.4076
# 2025-06-19 13:17:56 [INFO]: Epoch 004 - training loss (MAE): 1.0071, validation MSE: 1.3506
# 2025-06-19 13:18:23 [INFO]: Epoch 005 - training loss (MAE): 0.9624, validation MSE: 1.3022
# 2025-06-19 13:18:50 [INFO]: Epoch 006 - training loss (MAE): 0.9236, validation MSE: 1.2634
# 2025-06-19 13:19:18 [INFO]: Epoch 007 - training loss (MAE): 0.8939, validation MSE: 1.2339
# 2025-06-19 13:19:46 [INFO]: Epoch 008 - training loss (MAE): 0.8603, validation MSE: 1.2131
# 2025-06-19 13:20:14 [INFO]: Epoch 009 - training loss (MAE): 0.8317, validation MSE: 1.1962
# 2025-06-19 13:20:41 [INFO]: Epoch 010 - training loss (MAE): 0.8072, validation MSE: 1.1820
# 2025-06-19 13:21:08 [INFO]: Epoch 011 - training loss (MAE): 0.7881, validation MSE: 1.1688
# 2025-06-19 13:21:34 [INFO]: Epoch 012 - training loss (MAE): 0.7679, validation MSE: 1.1579
# 2025-06-19 13:21:58 [INFO]: Epoch 013 - training loss (MAE): 0.7503, validation MSE: 1.1498
# 2025-06-19 13:22:22 [INFO]: Epoch 014 - training loss (MAE): 0.7331, validation MSE: 1.1383
# 2025-06-19 13:22:46 [INFO]: Epoch 015 - training loss (MAE): 0.7215, validation MSE: 1.1196
# 2025-06-19 13:23:09 [INFO]: Epoch 016 - training loss (MAE): 0.7071, validation MSE: 1.0994
# 2025-06-19 13:23:33 [INFO]: Epoch 017 - training loss (MAE): 0.6975, validation MSE: 1.0791
# 2025-06-19 13:23:57 [INFO]: Epoch 018 - training loss (MAE): 0.6863, validation MSE: 1.0637
# 2025-06-19 13:24:22 [INFO]: Epoch 019 - training loss (MAE): 0.6766, validation MSE: 1.0578
# 2025-06-19 13:24:46 [INFO]: Epoch 020 - training loss (MAE): 0.6687, validation MSE: 1.0458
# 2025-06-19 13:25:09 [INFO]: Epoch 021 - training loss (MAE): 0.6613, validation MSE: 1.0322
# 2025-06-19 13:25:32 [INFO]: Epoch 022 - training loss (MAE): 0.6540, validation MSE: 1.0178
# 2025-06-19 13:25:56 [INFO]: Epoch 023 - training loss (MAE): 0.6463, validation MSE: 1.0022
# 2025-06-19 13:26:18 [INFO]: Epoch 024 - training loss (MAE): 0.6391, validation MSE: 0.9895
# 2025-06-19 13:26:35 [INFO]: Epoch 025 - training loss (MAE): 0.6351, validation MSE: 0.9779
# 2025-06-19 13:26:35 [INFO]: Finished training. The best model is from epoch#25.
# 2025-06-19 13:26:35 [INFO]: Saved the model to ./brits_model\20250619_T131556\BRITS.pypots

# %%
# For evaluation, since BRITS does not have passed ground truth without missing values.

imputed = {}

# Impute missing values using the trained models
for cluster_id in range(len(clusters)):
    imputed[cluster_id] = {}
    for rate in missing_rates:
        key = int(rate * 100)
        imputed[cluster_id][key] = models[cluster_id][key].impute(val_data[cluster_id][key])

# %% [markdown]
# ### Unscale data before evaluation

# %%
import joblib

imputed_unscaled = {}

for cluster_id in range(len(clusters)):
    imputed_unscaled[cluster_id] = {}
    
    scaler = joblib.load(f"speed_scaler_{cluster_id}.pkl")
    print(f"{type(scaler)}")

# Unscale the imputed values for each cluster and missing rate
    for rate in missing_rates:
        key = int(rate * 100)
        n_samples, n_steps, n_features = imputed[cluster_id][key].shape
        tensor_2d = imputed[cluster_id][key].reshape(-1, n_features)  # Flatten time dimension
        tensor_2d_unscaled = scaler.inverse_transform(tensor_2d)
        imputed_unscaled[cluster_id][key] = tensor_2d_unscaled.reshape(n_samples, n_steps, n_features)
# Out:
# <class 'sklearn.preprocessing._data.StandardScaler'>
# <class 'sklearn.preprocessing._data.StandardScaler'>
# <class 'sklearn.preprocessing._data.StandardScaler'>
# <class 'sklearn.preprocessing._data.StandardScaler'>

# %% [markdown]
# ## Evaluation

# %%
import numpy as np
from sklearn.metrics import r2_score

r2_scores = {}

for cluster_id in range(len(clusters)):
    r2_scores[cluster_id] = {}
    for rate in missing_rates:
        key = int(rate * 100)

        imputed = imputed_unscaled[cluster_id][key]
        original = X_val_full_unscaled_seq_tensor[cluster_id]
        mask = val_masks_seq[cluster_id][key]

        # Initialize list for per-feature R²
        feature_r2 = []

        for f in range(original.shape[2]):  # loop over features
            f_mask = mask[:, :, f]
            if not np.any(f_mask):
                continue  # skip if no missing values for this feature

            y_true = original[:, :, f][f_mask]
            y_pred = imputed[:, :, f][f_mask]

            if len(y_true) < 2:
                continue  # not enough points to compute R²

            r2 = r2_score(y_true, y_pred)
            feature_r2.append(r2)

        if feature_r2:
            r2_scores[cluster_id][key] = np.mean(feature_r2)
        else:
            r2_scores[cluster_id][key] = np.nan  # or 0 or another fallback

        print(f"R² Cluster {cluster_id} Rate {rate*100:.0f}%: {r2_scores[cluster_id][key]:.3f}")
# Out:
# R² Cluster 0 Rate 5%: 0.634
# R² Cluster 0 Rate 20%: 0.580
# R² Cluster 0 Rate 60%: 0.615
# R² Cluster 0 Rate 99%: 0.342
# R² Cluster 1 Rate 5%: 0.583
# R² Cluster 1 Rate 20%: 0.538
# R² Cluster 1 Rate 60%: 0.529
# R² Cluster 1 Rate 99%: 0.278
# R² Cluster 2 Rate 5%: 0.629
# R² Cluster 2 Rate 20%: 0.481
# R² Cluster 2 Rate 60%: 0.514
# R² Cluster 2 Rate 99%: 0.316
# R² Cluster 3 Rate 5%: 0.688
# R² Cluster 3 Rate 20%: 0.639
# R² Cluster 3 Rate 60%: 0.606
# R² Cluster 3 Rate 99%: 0.365

# %%
smape = {}
for cluster_id in range(len(clusters)):
    smape[cluster_id] = {}
    for rate in missing_rates:
        key = int(rate * 100)
        imputed = imputed_unscaled[cluster_id][key]  # shape (n_samples, n_steps, n_features)
        original = X_val_full_unscaled_seq_tensor[cluster_id]  # same shape
        mask = val_masks_seq[cluster_id][key]  # same shape (bool mask)

        n_samples, n_steps, n_features = original.shape

        feature_smapes = []
        for f in range(n_features):
            # Select the mask and data for feature f
            f_mask = mask[:, :, f]
            if not np.any(f_mask):
                continue  # skip if no missing values for this feature

            numerator = np.abs(imputed[:, :, f][f_mask] - original[:, :, f][f_mask])
            denominator = np.abs(imputed[:, :, f][f_mask]) + np.abs(original[:, :, f][f_mask]) + 1e-8
            smape_f = 100 * np.mean(2 * numerator / denominator)
            feature_smapes.append(smape_f)

        smape[cluster_id][key] = np.mean(feature_smapes) if feature_smapes else np.nan
        print(f"SMAPE Cluster {cluster_id} Rate {rate*100}%: {smape[cluster_id][key]:.2f}%")
# Out:
# SMAPE Cluster 0 Rate 5.0%: 51.30%
# SMAPE Cluster 0 Rate 20.0%: 49.95%
# SMAPE Cluster 0 Rate 60.0%: 38.02%
# SMAPE Cluster 0 Rate 99.0%: 43.57%
# SMAPE Cluster 1 Rate 5.0%: 58.71%
# SMAPE Cluster 1 Rate 20.0%: 45.01%
# SMAPE Cluster 1 Rate 60.0%: 39.93%
# SMAPE Cluster 1 Rate 99.0%: 45.10%
# SMAPE Cluster 2 Rate 5.0%: 63.06%
# SMAPE Cluster 2 Rate 20.0%: 50.54%
# SMAPE Cluster 2 Rate 60.0%: 35.86%
# SMAPE Cluster 2 Rate 99.0%: 37.15%
# SMAPE Cluster 3 Rate 5.0%: 53.36%
# SMAPE Cluster 3 Rate 20.0%: 45.25%
# SMAPE Cluster 3 Rate 60.0%: 32.28%
# SMAPE Cluster 3 Rate 99.0%: 40.01%

# %% [markdown]
# ### Average errors per feature

# %%
features_per_cluster = {i: X_val_full_unscaled_seq_tensor[i].shape[-1] for i in range(len(clusters))}

# %%
features_per_cluster
# Out:
# {0: 83, 1: 48, 2: 49, 3: 207}

# %%
n_clusters = len(clusters) - 1  # number of actual clusters
flow_all_id = len(clusters) - 1  # index of the full dataset

avg_r2_cluster = {}
r2_all = {}

for rate in missing_rates:
    key = int(rate * 100)

    # Gather NRMSE and weights (number of features per cluster)
    r2_values = np.array([r2_scores[cluster_id][key] for cluster_id in range(n_clusters)])
    feature_counts = np.array([features_per_cluster[cluster_id] for cluster_id in range(n_clusters)])

    # Compute weighted average
    weighted_avg = np.average(r2_values, weights=feature_counts)
    
    avg_r2_cluster[key] = weighted_avg
    r2_all[key] = r2_scores[flow_all_id][key]  # for full feature set

    print(f"Weighted Average NRMSE for rate {rate*100}%: {avg_r2_cluster[key]:.2f}%")
    print(f"NRMSE for full at rate {rate*100}%: {r2_all[key]:.2f}%")
# Out:
# Weighted Average NRMSE for rate 5.0%: 0.62%
# NRMSE for full at rate 5.0%: 0.69%
# Weighted Average NRMSE for rate 20.0%: 0.54%
# NRMSE for full at rate 20.0%: 0.64%
# Weighted Average NRMSE for rate 60.0%: 0.56%
# NRMSE for full at rate 60.0%: 0.61%
# Weighted Average NRMSE for rate 99.0%: 0.32%
# NRMSE for full at rate 99.0%: 0.37%

# %%
avg_smape_cluster = {}
smape_all = {}

for rate in missing_rates:
    key = int(rate * 100)
    
    # Gather SMAPE and weights (number of features per cluster)
    smape_values = np.array([smape[cluster_id][key] for cluster_id in range(n_clusters)])
    feature_counts = np.array([features_per_cluster[cluster_id] for cluster_id in range(n_clusters)])
    
    # Compute weighted average
    weighted_avg = np.average(smape_values, weights=feature_counts)
    
    avg_smape_cluster[key] = weighted_avg
    smape_all[key] = smape[flow_all_id][key]  # for full feature set
    
    print(f"Weighted Average SMAPE for rate {rate*100}%: {avg_smape_cluster[key]:.2f}%")
    print(f"SMAPE for full at rate {rate*100}%: {smape_all[key]:.2f}%")
# Out:
# Weighted Average SMAPE for rate 5.0%: 56.48%
# SMAPE for full at rate 5.0%: 53.36%
# Weighted Average SMAPE for rate 20.0%: 48.80%
# SMAPE for full at rate 20.0%: 45.25%
# Weighted Average SMAPE for rate 60.0%: 37.94%
# SMAPE for full at rate 60.0%: 32.28%
# Weighted Average SMAPE for rate 99.0%: 42.23%
# SMAPE for full at rate 99.0%: 40.01%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def plot_missing_vs_observed(data, mask, feature_name="flow"):
    """
    data: 1D array of original values
    mask: 1D boolean array, True if missing
    feature_name: for labeling
    """
    data_missing = data[mask]
    data_observed = data[~mask]

    plt.figure(figsize=(10, 5))
    sns.histplot(data_observed, color='blue', label='Observed', kde=True, stat="density", bins=30)
    sns.histplot(data_missing, color='red', label='Missing', kde=True, stat="density", bins=30)
    plt.title(f"Distribution of {feature_name} - Observed vs Missing")
    plt.xlabel(feature_name)
    plt.ylabel("Density")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_missing_vs_observed(X_val_full_unscaled_seq_tensor[0].flatten(), val_masks_seq[0][99].flatten(), feature_name="Flow at 20% missingness")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example error values (replace with your real variables)
missing_levels = ['5%', '20%', '60%', '99%']

# Bar chart setup
x = np.arange(len(missing_levels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# --- MAE plot ---
ax[0].bar(x - width/2, r2_all.values(), width, label='Without Semantics', color='tab:blue')
ax[0].bar(x + width/2, avg_r2_cluster.values(), width, label='With Semantics', color='tab:orange')
ax[0].set_ylabel('MAE')
ax[0].set_title('MAE by Missingness Level')
ax[0].legend()
ax[0].grid(True, axis='y', linestyle='--', alpha=0.6)

# --- SMAPE plot ---
ax[1].bar(x - width/2, smape_all.values(), width, label='Without Semantics', color='tab:blue')
ax[1].bar(x + width/2, avg_smape_cluster.values(), width, label='With Semantics', color='tab:orange')
ax[1].set_ylabel('SMAPE (%)')
ax[1].set_title('SMAPE by Missingness Level')
ax[1].set_xticks(x)
ax[1].set_xticklabels(missing_levels)
ax[1].legend()
ax[1].grid(True, axis='y', linestyle='--', alpha=0.6)

fig.tight_layout()
plt.show()
