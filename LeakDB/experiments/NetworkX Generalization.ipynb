# %% [markdown]
# ## Generic function that converts from KG to NetworkX

# %%
import enum

import networkx as nx
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS, XSD
import sys

def networkx(rdf_graph):
    """
    Convert an RDFLib graph to a NetworkX graph.
    - Nodes: All individuals and ontology classes.
    - Edges: Object properties create directed edges between nodes.
    - Attributes: Data properties are stored as node attributes.
    """
    if isinstance(rdf_graph, Graph) or isinstance(rdf_graph, str):
        if isinstance(rdf_graph, Graph):
            rdf_graph = rdf_graph
        elif isinstance(rdf_graph, str):
            if rdf_graph.endswith('.ttl'):
                try:
                    rdf_graph = Graph().parse(rdf_graph, format='turtle')
                except Exception as e:
                    print(f"Error parsing Turtle file: {e}")
                    return None
            else:
                print("Unexpected input format. Provide a Turtle (.ttl) file path.")
    else:
        print("Unexpected input format. Provide an RDFLib Graph or a .ttl file path.")
        return None

    # Initialize the directed graph
    nx_graph = nx.DiGraph()

    # Process the RDF graph
    for s, p, o in rdf_graph:
        s, p = s.toPython(), p.toPython()
        # Ensure subject is a node
        if s not in nx_graph:
            nx_graph.add_node(s)

        # Check if the object is a literal (data property) or an entity (object property)
        if isinstance(o, Literal):  # Data property → store as a node attribute
            nx_graph.nodes[s][p] = o.toPython()
        else:  # Object property → add an edge
            o = o.toPython()
            # in case o is not a hashable type, parse it to string
            if isinstance(o, enum.Enum):
                o = str(o)
            if p == RDF.type.toPython():
                nx_graph.nodes[s][RDF.type.toPython()] = o
            else:
                nx_graph.add_edge(s, o, predicate=p)

    return nx_graph

# %% [markdown]
# ## Generic function that extracts features from any NetworkX

# %%
g_nx_traffic  = networkx(r"D:\Master\Thesis\Code\traffic\metr-la\LA_traffic_KG.ttl")

# %%
import re
from rdflib import RDF

def shorten_uri(uri, ontology_base):
    """
    Extract the local name from a full URI. 
    Removes known ontology base and keeps suffix like Pipe_9 or diameter.
    """
    if uri.startswith(ontology_base):
        return uri.replace(ontology_base, "")
    elif "#" in uri:
        return uri.split("#")[-1]
    elif "/" in uri:
        return uri.split("/")[-1]
    else:
        return uri

def extract_features_from_nx_graph(nx_graph, ontology_base, edge_predicates, node_type_filter, attribute_keys):
    # nx_graph: NetworkX graph
    # ontology_base: Base URI of the ontology to shorten URIs
    # edge_predicates: Either LIST or None - edge predicates to include as attributes
    # node_type_filter: Either None or a specific type to filter nodes by
    # attribute_keys: Either LIST or None - of specific attributes to include

    feature_dict = {}
    rdf_type_key = shorten_uri(str(RDF.type), ontology_base)

    for node, data in nx_graph.nodes(data=True):
        #print(f"Processing node: {node}, data: {data}")

        # Shorten RDF.type value and all keys
        cleaned_data = {
            shorten_uri(k, ontology_base): v if not isinstance(v, str) else shorten_uri(v, ontology_base)
            for k, v in data.items()
        }

        #print(f"Cleaned data: {cleaned_data}")

        # Filter by type if specified
        node_type = cleaned_data.get(rdf_type_key)
        if node_type_filter and node_type != node_type_filter:
            continue

        # Shorten node URI
        node_id = shorten_uri(node, ontology_base)

        # Select attributes
        if attribute_keys:
            features = {k: cleaned_data[k] for k in attribute_keys if k in cleaned_data}
        else:
            # Remove rdf:type from features
            features = {k: v for k, v in cleaned_data.items() if k != rdf_type_key}

        # Now add edges as attributes if requested
        if edge_predicates:
            for _, target, edge_data in nx_graph.out_edges(node, data=True):
                pred = shorten_uri(edge_data.get("predicate", ""), ontology_base)
                if pred in edge_predicates:
                    target_id = shorten_uri(target, ontology_base)
                    
                    if pred in features:
                        if isinstance(features[pred], list):
                            features[pred].append(target_id)
                        else:
                            features[pred] = [features[pred], target_id]
                    else:
                        features[pred] = target_id  # or [target_id] if you always want a list

        #print(f"added Data: {features}")
        feature_dict[node_id] = features

    return feature_dict

# %% [markdown]
# ### Traffic Semantic Features

# %%
# Step 1: Extract traffic sensor data
sensor_features = extract_features_from_nx_graph(
    nx_graph=g_nx_traffic,
    ontology_base="http://example.org/traffic#",
    edge_predicates=["installedOn"],
    node_type_filter="TrafficSensor",
    attribute_keys=None,
)

# Step 2: Extract road segments with their attributes
road_features = extract_features_from_nx_graph(
    nx_graph=g_nx_traffic,
    ontology_base="http://example.org/traffic#",
    edge_predicates=None,
    node_type_filter="RoadSegment",
    attribute_keys=["roadType", "maxSpeed", "numberOfLanes"]
)

# %%
# Step 3: Link sensors to roads and build rows
traffic_features = []
for sensor_id, sensor_data in sensor_features.items():
    road_id = sensor_data.get("installedOn")
    if not road_id:
        continue
    road_data = road_features.get(road_id)
    if not road_data:
        continue
    row = {
        "sensor_id": sensor_id,
        "road_type": road_data.get("roadType", ""),
        "max_speed": float(road_data.get("maxSpeed", 0)),
        "num_lanes": int(road_data.get("numberOfLanes", 0))
    }
    traffic_features.append(row)

# %%
traffic_features
# Out:
# [{'sensor_id': 'sensor_759591',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_718204',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767509',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717452',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717465',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_767554',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_761599',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_768469',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_764424',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716960',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717463',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717572',
#   'road_type': 'bridleway',
#   'max_speed': -1.0,
#   'num_lanes': -1},
#  {'sensor_id': 'sensor_765164',
#   'road_type': 'motorway_link',
#   'max_speed': -1.0,
#   'num_lanes': 2},
#  {'sensor_id': 'sensor_718141',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_718379',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716328',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_759602',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717480',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_773939',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_773906',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717481',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717498',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769405',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_718066',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_716331',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717489',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_773974',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_764120',
#   'road_type': 'motorway_link',
#   'max_speed': -1.0,
#   'num_lanes': -1},
#  {'sensor_id': 'sensor_764101',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767621',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717462',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_772168',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_773880',
#   'road_type': 'residential',
#   'max_speed': -1.0,
#   'num_lanes': -1},
#  {'sensor_id': 'sensor_767751',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_717570',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767495',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_768066',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_771667',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717573',
#   'road_type': 'motorway_link',
#   'max_speed': -1.0,
#   'num_lanes': 2},
#  {'sensor_id': 'sensor_716958',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_718064',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_769431',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_717819',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717446',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_716943',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717610',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_774012',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717445',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_764794',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_769346',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716939',
#   'road_type': 'primary',
#   'max_speed': 35.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717821',
#   'road_type': 'primary',
#   'max_speed': 35.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_717608',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717483',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717456',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_769372',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717458',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717578',
#   'road_type': 'cycleway',
#   'max_speed': -1.0,
#   'num_lanes': -1},
#  {'sensor_id': 'sensor_765273',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769418',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_718045',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_716953',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_773869',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_773927',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_772151',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769373',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_718089',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_773975',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716942',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_772513',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_767351',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717453',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_760024',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_718371',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769443',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_772178',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717513',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_773953',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767750',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_772596',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717576',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769430',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_767572',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769402',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_772140',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_773954',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_718499',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767350',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717459',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_769345',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716949',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_718072',
#   'road_type': 'motorway_link',
#   'max_speed': -1.0,
#   'num_lanes': 1},
#  {'sensor_id': 'sensor_773916',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_767541',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_773023',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_767494',
#   'road_type': 'motorway_link',
#   'max_speed': -1.0,
#   'num_lanes': 1},
#  {'sensor_id': 'sensor_769467',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716339',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_765171',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_771673',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717468',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717466',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_774067',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_717493',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717460',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_772669',
#   'road_type': 'path',
#   'max_speed': -1.0,
#   'num_lanes': -1},
#  {'sensor_id': 'sensor_764781',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717461',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717450',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717491',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767523',
#   'road_type': 'motorway_link',
#   'max_speed': -1.0,
#   'num_lanes': -1},
#  {'sensor_id': 'sensor_764853',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717469',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717473',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_767454',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_764760',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716337',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_764858',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_773904',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_763995',
#   'road_type': 'motorway_link',
#   'max_speed': -1.0,
#   'num_lanes': 1},
#  {'sensor_id': 'sensor_717488',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_773024',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_773062',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_773012',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_765265',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_762329',
#   'road_type': 'motorway_link',
#   'max_speed': -1.0,
#   'num_lanes': 1},
#  {'sensor_id': 'sensor_717571',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717447',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_718090',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_764766',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717818',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769444',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717823',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769403',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_760650',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_765176',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767455',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_767542',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717472',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_764106',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_765182',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_773995',
#   'road_type': 'motorway_link',
#   'max_speed': 65.0,
#   'num_lanes': 1},
#  {'sensor_id': 'sensor_767620',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717502',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_769388',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_716955',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_774011',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_772597',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769359',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716956',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_765099',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_769358',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_737529',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717499',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_761003',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717486',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716571',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717504',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717592',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717492',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_773013',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 3},
#  {'sensor_id': 'sensor_717825',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767573',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_772167',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_764949',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716941',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717495',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717508',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767053',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_761604',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_767366',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_765604',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717595',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717816',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6},
#  {'sensor_id': 'sensor_717490',
#   'road_type': 'motorway',
#   'max_speed': 55.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_716951',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 4},
#  {'sensor_id': 'sensor_717497',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_773996',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717510',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 5},
#  {'sensor_id': 'sensor_717804',
#   'road_type': 'motorway',
#   'max_speed': 65.0,
#   'num_lanes': 6}]

# %% [markdown]
# #### Pipe Semantic Features

# %%
g_nx_leakdb = networkx("KGS/knowledge_graph1-LeakDB.ttl")

# %%
pipe_features = extract_features_from_nx_graph(
    g_nx_leakdb,
   "https://raw.githubusercontent.com/DiTEC-project/wdn-knowledge-graph/refs/heads/main/wdn_ontology.ttl",
    node_type_filter="Pipe",  # Or full URI if you want
    attribute_keys=["diameter", "length", "roughness", "status"],
    edge_predicates=None
)

# %%
pipe_features
# Out:
# {'Pipe_9': {'diameter': 0.9925071,
#   'length': 815.7009,
#   'roughness': 132.6997,
#   'status': 'Open'},
#  'Pipe_3': {'diameter': 0.9429965,
#   'length': 942.114,
#   'roughness': 142.5124,
#   'status': 'Open'},
#  'Pipe_18': {'diameter': 0.6055914,
#   'length': 782.5734,
#   'roughness': 120.8565,
#   'status': 'Open'},
#  'Pipe_8': {'diameter': 1.038202,
#   'length': 857.5721,
#   'roughness': 125.6884,
#   'status': 'Open'},
#  'Pipe_11': {'diameter': 0.8017894,
#   'length': 1238.727,
#   'roughness': 134.9172,
#   'status': 'Open'},
#  'Pipe_23': {'diameter': 1.046681,
#   'length': 2714.027,
#   'roughness': 118.6827,
#   'status': 'Open'},
#  'Pipe_22': {'diameter': 0.3135412,
#   'length': 506.56,
#   'roughness': 120.6469,
#   'status': 'Open'},
#  'Pipe_16': {'diameter': 0.3693999,
#   'length': 2858.393,
#   'roughness': 131.5999,
#   'status': 'Open'},
#  'Pipe_19': {'diameter': 0.5864745,
#   'length': 403.2065,
#   'roughness': 132.9782,
#   'status': 'Open'},
#  'Pipe_4': {'diameter': 1.046316,
#   'length': 1177.574,
#   'roughness': 139.6072,
#   'status': 'Open'},
#  'Pipe_20': {'diameter': 0.9507895,
#   'length': 2252.831,
#   'roughness': 121.7172,
#   'status': 'Open'},
#  'Pipe_6': {'diameter': 1.039976,
#   'length': 437.3368,
#   'roughness': 129.394,
#   'status': 'Open'},
#  'Pipe_27': {'diameter': 0.2743641,
#   'length': 285.6935,
#   'roughness': 131.8654,
#   'status': 'Open'},
#  'Pipe_30': {'diameter': 0.4122381,
#   'length': 1997.237,
#   'roughness': 126.4847,
#   'status': 'Open'},
#  'Pipe_31': {'diameter': 0.2942326,
#   'length': 1553.082,
#   'roughness': 121.5079,
#   'status': 'Open'},
#  'Pipe_12': {'diameter': 0.6100255,
#   'length': 3352.516,
#   'roughness': 129.3119,
#   'status': 'Open'},
#  'Pipe_26': {'diameter': 0.4774439,
#   'length': 825.7778,
#   'roughness': 132.1164,
#   'status': 'Open'},
#  'Pipe_1': {'diameter': 1.032579,
#   'length': 101.8227,
#   'roughness': 132.0315,
#   'status': 'Open'},
#  'Pipe_5': {'diameter': 1.090574,
#   'length': 1451.77,
#   'roughness': 140.6532,
#   'status': 'Open'},
#  'Pipe_24': {'diameter': 0.7565249,
#   'length': 1193.236,
#   'roughness': 141.5037,
#   'status': 'Open'},
#  'Pipe_28': {'diameter': 0.3131806,
#   'length': 773.1004,
#   'roughness': 131.7228,
#   'status': 'Open'},
#  'Pipe_15': {'diameter': 0.2939906,
#   'length': 550.52,
#   'roughness': 135.7511,
#   'status': 'Open'},
#  'Pipe_2': {'diameter': 0.9509962,
#   'length': 1337.507,
#   'roughness': 120.4167,
#   'status': 'Open'},
#  'Pipe_13': {'diameter': 0.4325173,
#   'length': 801.1631,
#   'roughness': 142.5197,
#   'status': 'Open'},
#  'Pipe_33': {'diameter': 0.4413251,
#   'length': 892.1622,
#   'roughness': 126.9478,
#   'status': 'Open'},
#  'Pipe_29': {'diameter': 0.4185538,
#   'length': 1556.4,
#   'roughness': 134.4003,
#   'status': 'Open'},
#  'Pipe_10': {'diameter': 0.7810109,
#   'length': 987.5174,
#   'roughness': 117.0064,
#   'status': 'Open'},
#  'Pipe_32': {'diameter': 0.3185912,
#   'length': 153.1708,
#   'roughness': 130.3373,
#   'status': 'Open'},
#  'Pipe_34': {'diameter': 0.4921122,
#   'length': 970.7698,
#   'roughness': 119.2366,
#   'status': 'Open'},
#  'Pipe_21': {'diameter': 0.5523491,
#   'length': 1443.366,
#   'roughness': 124.3549,
#   'status': 'Open'},
#  'Pipe_25': {'diameter': 0.7376673,
#   'length': 1256.235,
#   'roughness': 127.0521,
#   'status': 'Open'},
#  'Pipe_7': {'diameter': 1.056082,
#   'length': 837.9012,
#   'roughness': 127.8199,
#   'status': 'Open'},
#  'Pipe_14': {'diameter': 0.4102378,
#   'length': 522.6046,
#   'roughness': 137.8775,
#   'status': 'Open'},
#  'Pipe_17': {'diameter': 0.5142606,
#   'length': 1773.933,
#   'roughness': 137.0129,
#   'status': 'Open'}}

# %% [markdown]
# ### MotionSense Semantic Features

# %%
g_nx_motionsense = networkx("D:\Master\Thesis\Code\motion-sense\motion_sense_ssn_kg.ttl")

# %%
motionSense_features = extract_features_from_nx_graph(
    g_nx_motionsense,
   "http://example.org/motion-sense#",
    node_type_filter="Participant",  # Or full URI if you want
    attribute_keys= ["hasGender"],
    edge_predicates=None
)

# %%
motionSense_features
# Out:
# {'Participant_P014': {'hasGender': 1},
#  'Participant_P005': {'hasGender': 0},
#  'Participant_P021': {'hasGender': 1},
#  'Participant_P010': {'hasGender': 0},
#  'Participant_P024': {'hasGender': 0},
#  'Participant_P004': {'hasGender': 1},
#  'Participant_P016': {'hasGender': 0},
#  'Participant_P013': {'hasGender': 1},
#  'Participant_P020': {'hasGender': 1},
#  'Participant_P017': {'hasGender': 1},
#  'Participant_P019': {'hasGender': 0},
#  'Participant_P009': {'hasGender': 1},
#  'Participant_P023': {'hasGender': 0},
#  'Participant_P018': {'hasGender': 0},
#  'Participant_P008': {'hasGender': 0},
#  'Participant_P003': {'hasGender': 0},
#  'Participant_P012': {'hasGender': 1},
#  'Participant_P001': {'hasGender': 1},
#  'Participant_P002': {'hasGender': 1},
#  'Participant_P007': {'hasGender': 0},
#  'Participant_P006': {'hasGender': 1},
#  'Participant_P011': {'hasGender': 1},
#  'Participant_P022': {'hasGender': 1},
#  'Participant_P015': {'hasGender': 1}}

# %% [markdown]
# ### LBNL Semantic Features

# %%
g_nx_lbnl = networkx("D:\Master\Thesis\Code\LBNL_FDD_Dataset_FCU\LBNL_Ontology_Original.ttl")

# %%
lbnl_features = extract_features_from_nx_graph(
    g_nx_lbnl,
   "http://example.org/motion-sense#",
    node_type_filter=None,  # Or full URI if you want
    attribute_keys= ["type"],
    edge_predicates=["hasPoint"]
)

# %%
lbnl_features
# Out:
# {'FCU': {'type': 'FCU',
#   'hasPoint': ['FCU_DA_CFM',
#    'FCU_RA_HUMD',
#    'FCU_CTRL',
#    'FCU_RAT',
#    'FCU_DA_HUMD',
#    'FCU_MAT',
#    'FCU_DAT',
#    'FCU_OAT',
#    'FCU_OA_CFM',
#    'FCU_OA_HUMD',
#    'FCU_MA_HUMD']},
#  'Supply_air_fan': {'type': 'Fan',
#   'hasPoint': ['FCU_SPD', 'FCU_WAT', 'FAN_CTRL']},
#  'FCU_OA_HUMD': {'type': 'Outside_Air_Humidity_Sensor'},
#  'Cooling_coil': {'type': 'Chilled_Water_Coil',
#   'hasPoint': ['FCU_CLG_GPM',
#    'FCU_CLG_RWT',
#    'FCU_CVLV',
#    'FCU_CLG_EWT',
#    'FCU_CVLV_DM']},
#  'FCU_CLG_GPM': {'type': 'Chilled_Water_Supply_Flow_Sensor'},
#  'Outdoor_air_damper': {'type': 'Outside_Damper',
#   'hasPoint': ['FCU_DMPR', 'FCU_DMPR_DM']},
#  'FCU_DMPR': {'type': 'Damper_Position_Sensor'},
#  'FCU_MA_HUMD': {'type': 'Mixed_Air_Humidity_Sensor'},
#  'FCU_HTG_EWT': {'type': 'Entering_Water_Temperature_Sensor'},
#  'FCU_SPD': {'type': 'Speed_Status'},
#  'FCU_DAT': {'type': 'Discharge_Air_Temperature_Sensor'},
#  'Zone': {'type': 'Zone', 'hasPoint': ['RMHTGSPT', 'RM_TEMP', 'RMCLGSPT']},
#  'RMHTGSPT': {'type': 'Zone_Air_Heating_Temperature_Setpoint'},
#  'FCU_MAT': {'type': 'Mixed_Air_Temperature_Sensor'},
#  'Heating_coil': {'type': 'Hot_Water_Coil',
#   'hasPoint': ['FCU_HTG_RWT',
#    'FCU_HTG_GPM',
#    'FCU_HVLV_DM',
#    'FCU_HVLV',
#    'FCU_HTG_EWT']},
#  'FCU_CLG_RWT': {'type': 'Leaving_Water_Temperature_Sensor'},
#  'RMCLGSPT': {'type': 'Zone_Air_Cooling_Temperature_Setpoint'},
#  'FCU_HVLV_DM': {'type': 'Valve_Command'},
#  'FCU_HTG_RWT': {'type': 'Leaving_Water_Temperature_Sensor'},
#  'FCU_DA_CFM': {'type': 'Discharge_Air_Flow_Sensor'},
#  'FCU_WAT': {'type': 'Electricial_Meter'},
#  'FCU_HTG_GPM': {'type': 'Hot_Water_Supply_Flow_Sensor'},
#  'FCU_RA_HUMD': {'type': 'Return_Air_Humidity_Sensor'},
#  'FCU_DMPR_DM': {'type': 'Damper_Position_Command'},
#  'FCU_CTRL': {'type': 'Mode_Command'},
#  'FAN_CTRL': {'type': 'Mode_Command'},
#  'FCU_OAT': {'type': 'Outside_Air_Temperature_Sensor'},
#  'FCU_CLG_EWT': {'type': 'Entering_Water_Temperature_Sensor'},
#  'FCU_CVLV': {'type': 'Valve_Position_Sensor'},
#  'FCU_RAT': {'type': 'Return_Air_Temperature_Sensor'},
#  'FCU_DA_HUMD': {'type': 'Discharge_Air_Humidity_Sensor'},
#  'FCU_HVLV': {'type': 'Valve_Position_Sensor'},
#  'RM_TEMP': {'type': 'Zone_Air_Temperature_Sensor'},
#  'FCU_OA_CFM': {'type': 'Outside_Air_Flow_Sensor'},
#  'FCU_CVLV_DM': {'type': 'Valve_Command'}}

# %% [markdown]
# ### OfficeGraph Semantic features

# %%
g_nx_officeGraph = networkx("D:\Master\Thesis\Code\OfficeGraph\devices_in_rooms.ttl")

# %%
officeGraph_features = extract_features_from_nx_graph(
    g_nx_officeGraph,
   "https://saref.etsi.org/saref4bldg/",
    node_type_filter=None,  # Or full URI if you want
    attribute_keys= None,
    edge_predicates=None
)

# %%
officeGraph_features
# Out:
# {'zone_VL-F1-O4-M50': {'comment': 'support_zone'},
#  'zone_VL-F1-W1-W40': {'comment': 'support_zone'},
#  'zone_VL-F2-W4-38': {'comment': 'support_zone'},
#  'VL_floor_2': {},
#  'zone_VL-F3-O3-A-29': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-A-11': {'comment': 'support_zone'},
#  'R5_177': {},
#  'device_urn:Device:SmartThings:44f87a6f-4660-4441-beb7-5e1e1a8a34d2': {},
#  'zone_VL-F4-O4-M38': {'comment': 'support_zone'},
#  'R5_14': {},
#  'roomname_3.067': {'comment': 'room'},
#  'zone_VL-F5-WEST-M-48': {'comment': 'support_zone'},
#  'VL_floor_5': {},
#  'roomname_4.005': {'comment': 'room'},
#  'device_urn:Device:SmartThings:81b4c38c-0622-47a0-a932-8087d28097b4': {},
#  'R5_114': {},
#  'roomname_3.015': {'comment': 'room'},
#  'zone_VL-F2-W-W7': {'comment': 'support_zone'},
#  'zone_VL-F3-O3-W29C': {'comment': 'support_zone'},
#  'zone_VL-F3-O4-T40': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:0a1498b7-650a-48d5-9c69-37731e181bbb': {},
#  'zone_Energie_verbruik_gebouw_videolab': {'comment': 'support_zone'},
#  'device_871687910000393813-00061630': {},
#  'roomname_3.021': {'comment': 'room'},
#  'device_urn:Device:SmartThings:6843790c-f020-4e64-b803-61fa1439cd1e': {},
#  'zone_VL-F3-W1-M27': {'comment': 'support_zone'},
#  'zone_VL-F2-O3-T49': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:cfc492e9-eeed-4947-b683-e39b1747f10a': {},
#  'zone_VL-F6-W1-W29': {'comment': 'support_zone'},
#  'zone_VL-F1-W1-M41': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:f0a2ace6-5196-43d8-8492-577839b99b03': {},
#  'device_C46FAO': {},
#  'zone_VL-F2-O3-51': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:47b77a17-7769-487c-bb63-b92f379a4cbb': {},
#  'roomname_4.032': {'comment': 'room'},
#  'device_urn:Device:SmartThings:861a9a7e-e00d-4230-b836-ae6a31978cd9': {},
#  'roomname_4.012': {'comment': 'room'},
#  'zone_VL-F4-O4-W34': {'comment': 'support_zone'},
#  'roomname_1.029B': {'comment': 'room'},
#  'zone_VL-F6-O3-T30A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:bc196f7e-3d1c-4dec-aa85-95e71a2ebf39': {},
#  'zone_VL-F1-O3-W16-B': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:01446d13-59fa-4c19-ac22-c5a7101bea49': {},
#  'zone_VL-F3-W1-M10': {'comment': 'support_zone'},
#  'VL_floor_3': {},
#  'roomname_3.033': {'comment': 'room'},
#  'device_urn:Device:SmartThings:83b04066-b274-49a4-9fea-bb183b5a41e9': {},
#  'device_C31D40': {},
#  'roomname_7.035': {'comment': 'room'},
#  'roomname_4.034': {'comment': 'room'},
#  'device_urn:Device:SmartThings:ae0e1240-4b6f-4416-a796-1d79d63b1998': {},
#  'zone_VL-F5-WEST-A-11863': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-T-71': {'comment': 'support_zone'},
#  'roomname_3.069': {'comment': 'room'},
#  'R5_225': {},
#  'zone_VL-F2-O1-W3': {'comment': 'support_zone'},
#  'roomname_1.074': {'comment': 'room'},
#  'VL_floor_1': {},
#  'roomname_4.055': {'comment': 'room'},
#  'device_urn:Device:SmartThings:f7e79ad0-6e0d-4f2a-a2db-1d8be3757d23': {},
#  'zone_VL-F2-O3-M46': {'comment': 'support_zone'},
#  'zone_VL-F4-W1A-M49': {'comment': 'support_zone'},
#  'zone_VL-F7-O2-M26': {'comment': 'support_zone'},
#  'zone_VL-F4-_W1A_-_30': {'comment': 'support_zone'},
#  'VL_floor_4': {},
#  'R5_60': {},
#  'roomname_3.072': {'comment': 'room'},
#  'zone_VL-F2-W-M37': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:bb413e7c-8364-4432-9f8e-7504365682f0': {},
#  'roomname_4.077': {'comment': 'room'},
#  'device_urn:Device:SmartThings:f3d27a77-2e22-4eea-8ad2-408e35e749fe': {},
#  'device_videolab-priva-controller102-floor1-left': {},
#  'zone_videolab-priva-controller102-floor1-left': {'comment': 'support_zone'},
#  'zone_VL-F5-OOST-T-22': {'comment': 'support_zone'},
#  'roomname_4.01': {'comment': 'room'},
#  'device_urn:Device:SmartThings:7ee646bb-e75e-4bf5-beff-79c2feeac646': {},
#  'R5_96': {},
#  'zone_VL-F4-04-38': {'comment': 'support_zone'},
#  'zone_VL-F7-O3-M30': {'comment': 'support_zone'},
#  'VL_floor_7': {},
#  'device_urn:Device:SmartThings:fafa7b29-1e04-495d-aa1b-2461ba2e735a': {},
#  'zone_VL-F1-W1-M40': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:4bb9b154-168d-4877-9112-a8755be4ba4e': {},
#  'zone_VL-F5-OOST-A-9018': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e5a1f363-d9c0-4cb4-a9e5-bea630d08321': {},
#  'roomname_3.002': {'comment': 'room'},
#  'zone_VL-F4-O2-T1': {'comment': 'support_zone'},
#  'roomname_4.059': {'comment': 'room'},
#  'device_urn:Device:SmartThings:412ae63c-7dc5-4c4a-aabe-f1052637cb9a': {},
#  'roomname_1.013': {'comment': 'room'},
#  'roomname_1.014': {'comment': 'room'},
#  'device_urn:Device:SmartThings:4632527c-1e17-49e8-af50-a6786397f324': {},
#  'device_urn:Device:SmartThings:c0c4a0d2-aeda-424e-85d3-281b84b36fa2': {},
#  'device_urn:Device:SmartThings:93a701b6-503c-4847-a5bb-fe3a203dbcc3': {},
#  'zone_VL-F5-WEST-T73': {'comment': 'support_zone'},
#  'zone_VL-F5-OOST-T-wissen9': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-T8': {'comment': 'support_zone'},
#  'zone_VL-F2-W-W11': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:2ceb4301-67ce-4cf3-a0d0-ff31d6d7bf3c': {},
#  'zone_VL-F7-W1-M3': {'comment': 'support_zone'},
#  'zone_VL-F5-OOST-W-6': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:49f42acd-2f39-423b-b7a8-0e7a8d290a28': {},
#  'zone_VL-F4-04-39': {'comment': 'support_zone'},
#  'zone_VL-F4-O3-M9': {'comment': 'support_zone'},
#  'roomname_7.073': {'comment': 'room'},
#  'zone_VL-F2-O3-M52': {'comment': 'support_zone'},
#  'zone_VL-F4-O4-M34': {'comment': 'support_zone'},
#  'zone_VL-F1-O4-T48': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-M-58': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:863d9eb5-1e88-446b-9714-f8ae942cebdc': {},
#  'R5_108': {},
#  'roomname_2.01': {'comment': 'room'},
#  'device_C2F7DF': {},
#  'roomname_2.051': {'comment': 'room'},
#  'device_urn:Device:SmartThings:26ee9a54-db2a-48f2-b2d8-1e1e1b793891': {},
#  'zone_VL-F2-O3-M47': {'comment': 'support_zone'},
#  'zone_VL-F4-O3-M19': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-T6': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:c33ea0b1-3d90-4dd4-bbd0-bca4acf01b27': {},
#  'zone_VL-F2-W-W6': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:96df1542-e92d-4be0-8741-9969f4afd342': {},
#  'roomname_1.005': {'comment': 'room'},
#  'roomname_3.007': {'comment': 'room'},
#  'R5_48': {},
#  'zone_VL-F7-W1-M23': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:8617e6b2-7721-446c-9098-6c144db58a5d': {},
#  'SmartSense_Multi_Sensor_91': {},
#  'zone_VL-F5-OOST-W-26': {'comment': 'support_zone'},
#  'zone_VL-F6-O4-T52': {'comment': 'support_zone'},
#  'zone_VL-F2-W-W8': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:7d4fc071-3d8d-44d0-aa43-2d25d429bb18': {},
#  'zone_VL-F4-W1A-W13b': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:cf57174e-6abe-42e1-9ad3-0f06026a6360': {},
#  'zone_VL-F2-W-T25B': {'comment': 'support_zone'},
#  'device_C30522': {},
#  'zone_VL-F6-W1-A-12': {'comment': 'support_zone'},
#  'zone_VL-F2-W-T11': {'comment': 'support_zone'},
#  'SmartSense_Multi_Sensor_68': {},
#  'zone_VL-F7-O3-W36a': {'comment': 'support_zone'},
#  'device_C2F387': {},
#  'zone_VL-F7-Oost-54': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:eaa246fc-8ab7-4002-9203-f525c68ebf87': {},
#  'zone_VL-F4-W1B-W27': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e335667c-e6d6-4bd2-9ee3-668106fd3176': {},
#  'zone_videolab-priva-controller102-floor1-right': {'comment': 'support_zone'},
#  'zone_VL-F4-W1A-M6': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:539817b5-b211-4d19-a3af-0a1552da2f3b': {},
#  'zone_VL-F6-O3-A-29-B': {'comment': 'support_zone'},
#  'zone_VL-F1-O2-W7': {'comment': 'support_zone'},
#  'roomname_7.022': {'comment': 'room'},
#  'device_urn:Device:SmartThings:dfce14d7-59e0-4955-b151-48086273da51': {},
#  'zone_VL-F6-W1-A-31': {'comment': 'support_zone'},
#  'roomname_7.045': {'comment': 'room'},
#  'device_urn:Device:SmartThings:23f2040e-cd51-4619-9736-aec7a399e7fc': {},
#  'device_C2F371': {},
#  'zone_VL-F7-Oost-30': {'comment': 'support_zone'},
#  'device_C2FC4A': {},
#  'zone_VL-F7-Oost-20': {'comment': 'support_zone'},
#  'zone_VL-F2-O-T10': {'comment': 'support_zone'},
#  'zone_VL-F7-O3-W9': {'comment': 'support_zone'},
#  'R5_45': {},
#  'zone_VL-F3-W1-A-17': {'comment': 'support_zone'},
#  'roomname_4.049': {'comment': 'room'},
#  'device_urn:Device:SmartThings:eaaeb59c-c11b-4a5c-afc5-ddca1f8aae73': {},
#  'roomname_4.002': {'comment': 'room'},
#  'device_urn:Device:SmartThings:285d08a0-5594-4328-87ea-e00297b686ac': {},
#  'R5_116': {},
#  'roomname_2.035': {'comment': 'room'},
#  'SmartSense_Multi_Sensor_19': {},
#  'zone_VL-F5-WEST-W-41': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-M20': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-T27': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:0b4670d7-8572-479a-858c-d914686ee17b': {},
#  'zone_VL-F5-OOST-A-13278': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:f0f66c72-9781-4128-b42a-e4909368e0e5': {},
#  'zone_VL-F5-WEST-M-42': {'comment': 'support_zone'},
#  'SmartSense_Motion_Sensor_29': {},
#  'device_urn:Device:SmartThings:b6c627c2-41d4-4b3e-a6e2-8f698fe00d96': {},
#  'zone_VL-F1-O3-W12': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-T5': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e1e84852-889f-4a81-b6c2-7f0130ff1a4d': {},
#  'roomname_3.058': {'comment': 'room'},
#  'device_urn:Device:SmartThings:2b9d91ed-9df9-48ce-a631-4774d6c2dfe2': {},
#  'zone_VL-F1-O4-M42': {'comment': 'support_zone'},
#  'zone_VL-F7-O3-T11': {'comment': 'support_zone'},
#  'zone_VL-F3-O2-A-21': {'comment': 'support_zone'},
#  'R5_8': {},
#  'device_urn:Device:SmartThings:e8b4d06a-df84-46e4-8f46-13b1c434c5fd': {},
#  'zone_VL-F4-W1B-T27': {'comment': 'support_zone'},
#  'zone_VL-F7-O2-M4-B': {'comment': 'support_zone'},
#  'R5_166': {},
#  'roomname_3.065': {'comment': 'room'},
#  'R5_37': {},
#  'roomname_1.071': {'comment': 'room'},
#  'zone_VL-F1-W1-A-39': {'comment': 'support_zone'},
#  'R5_88': {},
#  'roomname_3.037': {'comment': 'room'},
#  'device_urn:Device:SmartThings:e181a7d1-9526-4a4a-800e-b67b0a3c287e': {},
#  'roomname_7.037': {'comment': 'room'},
#  'device_C2FC45': {},
#  'zone_VL-F1-O4-W50': {'comment': 'support_zone'},
#  'R5_128': {},
#  'zone_VL-F4-_W1A_-_50': {'comment': 'support_zone'},
#  'zone_VL-F7-W1-M17': {'comment': 'support_zone'},
#  'zone_VL-F4-W1A-M52': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:50d3269a-fb25-4f33-981a-ce4fc70c2a5a': {},
#  'zone_VL-F6-O4-T46': {'comment': 'support_zone'},
#  'zone_VL-F2-O3-T46': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:b57b98b3-48ec-4b46-a2f4-0d688891d31d': {},
#  'roomname_4.054': {'comment': 'room'},
#  'device_urn:Device:SmartThings:7b335136-f535-45d6-936a-51b0fc8ff6bc': {},
#  'zone_VL-F5-WEST-T76': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:07f708f9-ed9b-49e9-ac75-cced6dae09fe': {},
#  'roomname_1.019': {'comment': 'room'},
#  'zone_VL-F7-W1-M7B': {'comment': 'support_zone'},
#  'zone_VL-F1-O2-A-1': {'comment': 'support_zone'},
#  'R5_113': {},
#  'roomname_1.031': {'comment': 'room'},
#  'R5_175': {},
#  'zone_Verdieping_1': {'comment': 'support_zone'},
#  'Hex_Doorcounter_Ver_1.0_8': {},
#  'zone_VL-F2-W4-41': {'comment': 'support_zone'},
#  'roomname_3.018B': {'comment': 'room'},
#  'roomname_3.06': {'comment': 'room'},
#  'device_urn:Device:SmartThings:033563c9-d2f1-4c6b-9ebc-0edea70d4afe': {},
#  'device_urn:Device:SmartThings:be298510-8592-4505-89af-20869f088fc0': {},
#  'zone_VL-F3-O3-M18': {'comment': 'support_zone'},
#  'roomname_1.006': {'comment': 'room'},
#  'device_urn:Device:SmartThings:dfd5c811-01e4-4c8b-a5ca-aef06f5526bc': {},
#  'device_urn:Device:SmartThings:ce899a08-60cc-4519-8308-940bda7fdfee': {},
#  'zone_VL-F5-OOST-T-11': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:6da6231f-f443-4c65-9a14-014e1620529e': {},
#  'zone_VL-F5-WEST-A-9198': {'comment': 'support_zone'},
#  'zone_VL-F1-W1-A-42': {'comment': 'support_zone'},
#  'R5_46': {},
#  'device_urn:Device:SmartThings:3020b43f-e19b-4dca-8407-bc5669dd48c3': {},
#  'roomname_7.004': {'comment': 'room'},
#  'zone_VL-F2-O3-A-46': {'comment': 'support_zone'},
#  'R5_213': {},
#  'zone_VL-F1-O4-A-50': {'comment': 'support_zone'},
#  'SmartSense_Multi_Sensor_71': {},
#  'roomname_1.07': {'comment': 'room'},
#  'device_urn:Device:SmartThings:0cdd9bde-35da-4bdd-a31d-a84715b0559d': {},
#  'R5_227': {},
#  'zone_VL-F6-W1-A-23': {'comment': 'support_zone'},
#  'zone_VL-F4-W1A-M48': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:84ce2c54-56b8-4f2e-858a-2b672c8a6f4d': {},
#  'zone_VL-F5-OOST-M-13': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-A-22': {'comment': 'support_zone'},
#  'roomname_7.034': {'comment': 'room'},
#  'zone_VL-F1-O2-M7': {'comment': 'support_zone'},
#  'zone_VL-F4-O2-T2': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-A-20': {'comment': 'support_zone'},
#  'VL_floor_6': {},
#  'zone_VL-F2-O-M16': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:a54dd196-9b6b-419a-b042-7c7116f98da6': {},
#  'roomname_2.002B': {'comment': 'room'},
#  'zone_VL-F3-W1-T1C': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:4b365e56-b4be-415d-8c0c-c49bc0224e73': {},
#  'device_urn:Device:SmartThings:d0868269-6364-45b5-8fa9-3b85b4edd0b9': {},
#  'zone_VL-F3-W1-W3': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:fe3634c8-c9d7-40f3-b0d6-cf9c35bcae7b': {},
#  'device_urn:Device:SmartThings:696da780-98e9-4eb7-b03e-35611b930aa2': {},
#  'zone_VL-F3-O3-W10': {'comment': 'support_zone'},
#  'zone_Videolab-F6-West-Hub1': {'comment': 'support_zone'},
#  'SmartPower_Outlet_1': {},
#  'zone_VL-F7-W1-T19': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-A-17-A': {'comment': 'support_zone'},
#  'R5_205': {},
#  'zone_VL_-F4-W1B-29': {'comment': 'support_zone'},
#  'roomname_1.028': {'comment': 'room'},
#  'zone_VL-F4-W1B-M34': {'comment': 'support_zone'},
#  'zone_VL-F1-O2-T9': {'comment': 'support_zone'},
#  'zone_VL-F5-OOST-M-17': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:edaae5ce-2a35-40ae-9a95-a34856f52128': {},
#  'zone_VL-F5-WEST-T42': {'comment': 'support_zone'},
#  'zone_VL-F4-W1A-M47': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-T-39': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:fa97d37b-0307-4d65-82c8-98a9ac003774': {},
#  'zone_VL-F4-O4-W39': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-W-50a': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:f2bcc448-b617-4518-ae8f-b21b98d392ea': {},
#  'zone_VL-F6-W1-M9': {'comment': 'support_zone'},
#  'roomname_7.043': {'comment': 'room'},
#  'zone_VL-F7-W1-W24': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:813f1ae8-f363-4e6c-bfd0-ceb40d6a8e3a': {},
#  'zone_VL-F6-O4HUB': {'comment': 'support_zone'},
#  'zone_VL-F1-O2-A-34': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-T15': {'comment': 'support_zone'},
#  'zone_VL-F6-O4-A-48': {'comment': 'support_zone'},
#  'zone_VL-F3-O4-A-34': {'comment': 'support_zone'},
#  'zone_VL-F4-O4-M40': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:be1a7a20-ef7a-4c34-980f-049181c26c26': {},
#  'zone_VL-F6-04-M49': {'comment': 'support_zone'},
#  'zone_VL-F4-W1B-T29': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:796c1673-e831-4b1a-b343-65fe3ba9ad1b': {},
#  'zone_VL-F5-OOST-M-1': {'comment': 'support_zone'},
#  'zone_VL-F6-04-M50': {'comment': 'support_zone'},
#  'zone_VL-F2-W-M14': {'comment': 'support_zone'},
#  'zone_VL-F3-O3-A-17': {'comment': 'support_zone'},
#  'roomname_3.011': {'comment': 'room'},
#  'device_urn:Device:SmartThings:1db584f4-cf4b-40e0-9a3b-6a2ef4a1566d': {},
#  'zone_VL-F4-_W1A_-_46': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:7547ea71-534f-4c08-a14b-a395618f8c82': {},
#  'device_urn:Device:SmartThings:b21a3bd5-fcb3-40bf-b33f-ca71609765b8': {},
#  'zone_VL-F2-W-W3': {'comment': 'support_zone'},
#  'zone_VL-F5-W1-44': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-T16-A': {'comment': 'support_zone'},
#  'zone_VL-F1-O4-M44': {'comment': 'support_zone'},
#  'roomname_7.066': {'comment': 'room'},
#  'device_C2EF16': {},
#  'zone_VL-F1-O4-T50': {'comment': 'support_zone'},
#  'zone_VL-F7-West-5': {'comment': 'support_zone'},
#  'zone_VL-F2-O3-W45': {'comment': 'support_zone'},
#  'zone_VL-F7-O4-W54': {'comment': 'support_zone'},
#  'zone_VL-F4-O2-W29': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:03b06c32-fdf0-450c-a10a-3e7bd8eb58dc': {},
#  'zone_Verdieping_3': {'comment': 'support_zone'},
#  'roomname_2.064': {'comment': 'room'},
#  'device_urn:Device:SmartThings:f284b1b5-77e2-4d04-b683-c9e15b865f20': {},
#  'zone_VL-F1-O4-A-44': {'comment': 'support_zone'},
#  'zone_VL-F7-O4-W50': {'comment': 'support_zone'},
#  'roomname_3.066': {'comment': 'room'},
#  'device_urn:Device:SmartThings:608974e1-cc93-4ba4-b74e-4edefb1350f7': {},
#  'zone_VL-F6-O3-W11': {'comment': 'support_zone'},
#  'zone_VL-F3-O3-M11': {'comment': 'support_zone'},
#  'R5_125': {},
#  'zone_VL-F6-W1-A-22': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:a8306d89-7911-4dab-95e2-6d61a04b2a73': {},
#  'roomname_2.002D': {'comment': 'room'},
#  'zone_VL-F1-W1-A-33': {'comment': 'support_zone'},
#  'R5_106': {},
#  'device_urn:Device:SmartThings:8e840b3f-495e-402b-b3e1-74c713dc1549': {},
#  'zone_VL-F3-O3-W29B': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-W1': {'comment': 'support_zone'},
#  'zone_VL-F2-O3-T47': {'comment': 'support_zone'},
#  'zone_VL_-F4-W1B-20': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:5ff7e4a9-62a2-4811-8106-829192053464': {},
#  'roomname_1.033': {'comment': 'room'},
#  'device_urn:Device:SmartThings:44048db2-d92a-4049-b733-46ee7ffcc58d': {},
#  'zone_VL-F4-O3-W8': {'comment': 'support_zone'},
#  'roomname_1.025A': {'comment': 'room'},
#  'zone_VL-F3-O2-T4': {'comment': 'support_zone'},
#  'zone_VL-F4-O2-M26': {'comment': 'support_zone'},
#  'zone_VL-F7-O2-T7': {'comment': 'support_zone'},
#  'roomname_3.005': {'comment': 'room'},
#  'device_urn:Device:SmartThings:7991b338-2e35-46aa-bb12-f1948d19f9f7': {},
#  'zone_VL-F3-O4-T34B': {'comment': 'support_zone'},
#  'zone_VL-F1-W1-A-41': {'comment': 'support_zone'},
#  'R5_34': {},
#  'zone_VL-F7-O2-T6': {'comment': 'support_zone'},
#  'roomname_2.022A': {'comment': 'room'},
#  'device_urn:Device:SmartThings:4c4a6adb-fdef-44b2-af61-84f582a5cd73': {},
#  'zone_VL-F2-O1-M1': {'comment': 'support_zone'},
#  'zone_VL-F4-O4-M42': {'comment': 'support_zone'},
#  'zone_VL-F7-Oost-7': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:8946bc46-23c5-47d8-8812-9a1729e1f7cc': {},
#  'zone_VL-F4-_W1A_-_13': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:a208d01b-c47c-4b27-b2d9-cd8e6c28aaab': {},
#  'zone_VL-F2-O1-M21': {'comment': 'support_zone'},
#  'zone_VL-F5-OOST-A-12625': {'comment': 'support_zone'},
#  'roomname_1.021': {'comment': 'room'},
#  'device_urn:Device:SmartThings:13b2c2d3-f167-49a5-bc03-a6d8ddee6eb6': {},
#  'zone_VL-F6-04-M42': {'comment': 'support_zone'},
#  'device_C2FC40': {},
#  'roomname_1.059': {'comment': 'room'},
#  'device_urn:Device:SmartThings:9ddadda7-d4ef-457d-ae06-db23fcc79a99': {},
#  'zone_VL-F7-W1-M20': {'comment': 'support_zone'},
#  'zone_VL-F2-O3-W50': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:7b29c91a-ca4f-497a-bd03-81b7e2250050': {},
#  'zone_VL-F7-West-7': {'comment': 'support_zone'},
#  'device_C4557E': {},
#  'zone_VL-F4-04-41': {'comment': 'support_zone'},
#  'R5_139': {},
#  'zone_VL-F3-O4-A-37': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:af06f372-908b-479a-9090-dd3a6087f927': {},
#  'device_urn:Device:SmartThings:ad41695e-bb29-41b2-9bd1-d42470ae0f8e': {},
#  'zone_VL-F3-W1-T13B': {'comment': 'support_zone'},
#  'roomname_7.02': {'comment': 'room'},
#  'device_urn:Device:SmartThings:a724fc4d-5602-4457-98db-98faebad46d5': {},
#  'roomname_2.017': {'comment': 'room'},
#  'device_urn:Device:SmartThings:bfffb1b0-7525-4cca-bd50-2fa4a20d72bc': {},
#  'zone_VL-F5-WEST-W-40': {'comment': 'support_zone'},
#  'zone_VL-F6-04-M44': {'comment': 'support_zone'},
#  'zone_VL-F4-O3_-18': {'comment': 'support_zone'},
#  'zone_VL-F1-W1-A-27': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-W8': {'comment': 'support_zone'},
#  'zone_VL-F1-O2-T1': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:4a4adb07-9d6d-4713-b5bc-cd26b9a04821': {},
#  'zone_VL-F4-W1A-W49': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-W40-B': {'comment': 'support_zone'},
#  'zone_VL-F2-W4-30': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:147f7543-baa4-4bf5-a09c-1c8e2915c555': {},
#  'zone_VL-F3-O3-M15': {'comment': 'support_zone'},
#  'zone_VL-F1-O2-M17': {'comment': 'support_zone'},
#  'zone_VL-F2-W-M27': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:701e3eb8-2a75-4e8e-bd54-591cdbca40d2': {},
#  'roomname_3.018D': {'comment': 'room'},
#  'device_urn:Device:SmartThings:ac9af171-6c7d-4d02-961b-635366a87e51': {},
#  'device_urn:Device:SmartThings:5c93ea4f-9c1d-4c29-974c-34447de9449c': {},
#  'zone_VL-F6-03-W14': {'comment': 'support_zone'},
#  'zone_VL-F5-OOST-A-12061': {'comment': 'support_zone'},
#  'zone_VL-F1-O4-M41': {'comment': 'support_zone'},
#  'zone_VL-F5-OOST-M-19': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:57955119-3af3-40fc-8d87-c68a9e8347a7': {},
#  'roomname_3.023': {'comment': 'room'},
#  'zone_VL-F5-WEST-A-9510': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:35437276-97e7-4f52-9f32-1e2c863f68b2': {},
#  'device_urn:Device:SmartThings:57dbf901-4c5d-4379-af3b-ff3f8e71c036': {},
#  'zone_VL-F3-O3-T16': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-M-38': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:211483a7-b26c-46d1-be18-45d9208edd3b': {},
#  'zone_VL-F4-W1A-T51': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-W8': {'comment': 'support_zone'},
#  'zone_VL-F2-O1-A-24': {'comment': 'support_zone'},
#  'R5_173': {},
#  'zone_VL-F2-W4-18': {'comment': 'support_zone'},
#  'zone_VL-F2-O1-W5': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:4ec0c9c1-4c34-4730-831d-0c65f73abbbd': {},
#  'zone_VL-F1-O4-A-42': {'comment': 'support_zone'},
#  'R5_182': {},
#  'zone_VL-F2-W-M1': {'comment': 'support_zone'},
#  'device_C31484': {},
#  'zone_VL-F7-Oost-55': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:90c86758-5a36-4f44-a6a9-6348d081eb82': {},
#  'roomname_3.068': {'comment': 'room'},
#  'device_urn:Device:SmartThings:bb2ef8a1-4cf5-4c7d-a96b-c9e470962111': {},
#  'zone_VL-F5-OOST-T-16': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:da141bd8-f28a-4b2c-8676-ba4f7c628cb1': {},
#  'roomname_2.012': {'comment': 'room'},
#  'zone_VL-F7-W1-W22': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e1caec2d-182e-44e7-9778-e0a0ff51dbd2': {},
#  'device_urn:Device:SmartThings:120ea09d-80f4-482d-a484-2356875ad6e8': {},
#  'zone_VL-F3-W1-M4': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:0ba4f2e1-97f8-447e-b48e-81e56407f7f7': {},
#  'zone_VL-F7-O3-M32': {'comment': 'support_zone'},
#  'roomname_4.009': {'comment': 'room'},
#  'device_urn:Device:SmartThings:32887500-fcc1-44d6-891d-46d50d97b41f': {},
#  'device_urn:Device:SmartThings:87e9c374-5c5b-4d56-9d31-621fcf17a870': {},
#  'roomname_1.002': {'comment': 'room'},
#  'device_urn:Device:SmartThings:02b0d079-4f7d-4773-a3dc-c2dd76753ecf': {},
#  'zone_VL-F1-O3-T31A': {'comment': 'support_zone'},
#  'zone_VL-F1-W1-A-38': {'comment': 'support_zone'},
#  'R5_172': {},
#  'zone_videolab-priva-controller102-floor4-right': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-T10': {'comment': 'support_zone'},
#  'zone_VL-F2-W-M42': {'comment': 'support_zone'},
#  'device_C2F7F1': {},
#  'roomname_7.046': {'comment': 'room'},
#  'zone_VL-F1-O2-A-18': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:7a7b9894-7f61-40c9-bf1d-0307668d2b1f': {},
#  'zone_VL-F3-O2-M4': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-W3': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:197581ec-2bee-41ba-a31c-37f439d0d0a6': {},
#  'zone_VL-F4-W1A-M45': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-M13': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-A-27': {'comment': 'support_zone'},
#  'zone_VL-F1-O4-T44': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:8d1ca808-74c9-46fc-b1c3-1ab8ebc58477': {},
#  'device_urn:Device:SmartThings:1e1edbc1-ff91-4e90-b764-c0ff68aec14d': {},
#  'zone_VL-F3-O3-M13': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:11e597ab-025b-44fe-ae2c-37a81a9d21e2': {},
#  'roomname_1.072': {'comment': 'room'},
#  'roomname_7.04': {'comment': 'room'},
#  'device_C323BA': {},
#  'roomname_7.009': {'comment': 'room'},
#  'zone_VL-F4-W1B-M25': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:3b02edef-5625-47dd-9d85-d41a4c7f319c': {},
#  'roomname_2.047': {'comment': 'room'},
#  'device_urn:Device:SmartThings:f1b87836-564c-40be-8c73-ac104b62a6fa': {},
#  'zone_VL-F4-W1A-M13': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:dfa2bde8-daf3-49c3-b272-e069ed80abc6': {},
#  'device_urn:Device:SmartThings:1795b518-d139-4f18-be05-bd0686479dd7': {},
#  'zone_VL-F7-O3-W16': {'comment': 'support_zone'},
#  'device_C46D04': {},
#  'zone_VL_-F4-W1B-41': {'comment': 'support_zone'},
#  'roomname_3.038': {'comment': 'room'},
#  'device_urn:Device:SmartThings:03c8ecc8-068b-433d-b09a-e00266641195': {},
#  'device_urn:Device:SmartThings:9619860e-6a17-4500-8a58-bf8b2266adf1': {},
#  'zone_VL-F4-W1A-T50': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:2447df66-88b7-432a-93d8-48df2259bca7': {},
#  'roomname_4.071': {'comment': 'room'},
#  'roomname_2.006': {'comment': 'room'},
#  'zone_VL-F5-WEST-HUB': {'comment': 'support_zone'},
#  'zone_VL-F7-Oost-48': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-D-50B': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-M40-B': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:0bd98077-36f3-463d-8480-8cb74df91c2a': {},
#  'zone_VL-F1-W1-W36': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-M23B': {'comment': 'support_zone'},
#  'SmartSense_Motion_Sensor_35': {},
#  'device_urn:Device:SmartThings:16cd51e2-7b17-43c8-9194-aa27ffada834': {},
#  'zone_VL-F3-O4-T34A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:b9f981ed-b558-4849-a29f-e630ddcfc942': {},
#  'zone_VL-F7-W1-T18': {'comment': 'support_zone'},
#  'zone_VL-F4-W1A-T4': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:1e636ea3-07e7-4068-8343-54c5df8f8bdb': {},
#  'R5_157': {},
#  'zone_VL-F3-W1-A-20': {'comment': 'support_zone'},
#  'zone_VL-F4-O2-M15': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-M-52': {'comment': 'support_zone'},
#  'SmartSense_Motion_Sensor_26': {},
#  'zone_VL-F2-W-W1A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:6e9d202d-dbaa-4a18-ba23-a268f725de29': {},
#  'zone_VL-F3-O3-A-30': {'comment': 'support_zone'},
#  'zone_videolab-priva-controller102-floor6-right': {'comment': 'support_zone'},
#  'device_C2EF30': {},
#  'zone_VL-F3-W1-A-14': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-T12': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:658fa399-1a59-4327-be3c-cd1980192fd8': {},
#  'zone_VL-F4-W1B-T11': {'comment': 'support_zone'},
#  'zone_VL-F4-O3-W22A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:af735d1e-a581-4937-a380-8c5a7c4f9e33': {},
#  'roomname_1.037A': {'comment': 'room'},
#  'zone_VL-F3-O3-A-33': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-M1': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:6638ff13-2142-4b2c-801d-a795e57ea2c1': {},
#  'device_urn:Device:SmartThings:2f9d5c46-e19f-45b2-a650-87a53c0d048d': {},
#  'zone_VL-F3-W1-T1B': {'comment': 'support_zone'},
#  'zone_VL-F3-O4-W35': {'comment': 'support_zone'},
#  'roomname_1.012': {'comment': 'room'},
#  'device_urn:Device:SmartThings:d0257540-0ff3-4916-bff8-6d5fdd1e4cf3': {},
#  'zone_VL-F1-O3-W40-A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:c858a271-d111-4ea7-8bbc-9bb484c8cbdd': {},
#  'zone_VL-F4-O2-W3': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:7210cbe1-da2b-45c2-8a86-024dd35f267e': {},
#  'device_urn:Device:SmartThings:bf6e5b5c-f7a4-45ea-9d44-86bee542c192': {},
#  'roomname_2.07': {'comment': 'room'},
#  'zone_VL-F1-O3-W31-B': {'comment': 'support_zone'},
#  'zone_VL-F1-O4-W46': {'comment': 'support_zone'},
#  'SmartSense_Multi_Sensor_32': {},
#  'zone_VL-F3-W1-A-19': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-T30': {'comment': 'support_zone'},
#  'zone_VL-F1-O4-W44': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e758e966-25be-4f1a-8815-b87bcafbe57d': {},
#  'zone_Videolab-F1-WestHub1': {'comment': 'support_zone'},
#  'zone_VL-F7-O2-W1': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-A-16': {'comment': 'support_zone'},
#  'zone_VL-F5-OOST-T-3': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:da535e31-02f0-4610-b4b1-3ff0302e8599': {},
#  'roomname_3.046': {'comment': 'room'},
#  'device_urn:Device:SmartThings:19e8ad6e-bc57-4cff-9447-a6902ff57694': {},
#  'zone_VL-F1-W1-M39': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:0c2769ce-27a9-44a8-b6e5-f2322f5ad8c1': {},
#  'R5_15': {},
#  'zone_VL-F1-O2-A-19': {'comment': 'support_zone'},
#  'zone_VL-F3-O3-A-12': {'comment': 'support_zone'},
#  'SmartSense_Multi_Sensor_70': {},
#  'SmartSense_Motion_Sensor_34': {},
#  'roomname_4.037': {'comment': 'room'},
#  'zone_VL-F5-WEST-M-62': {'comment': 'support_zone'},
#  'zone_VL-F6-O3-M23': {'comment': 'support_zone'},
#  'zone_VL-F7-O2-W6': {'comment': 'support_zone'},
#  'zone_VL-F7-W1-T1A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:b23e51b0-1a1c-4a00-926b-f4ac64d1a334': {},
#  'roomname_2.036A': {'comment': 'room'},
#  'zone_VL-F3-W1-M8': {'comment': 'support_zone'},
#  'zone_VL-F4-O3-M11': {'comment': 'support_zone'},
#  'zone_VL-F7-O2-M25': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:da8dbb21-5c5a-490e-affa-30c6ed6bcf7b': {},
#  'zone_VL-F4-W1A-W52': {'comment': 'support_zone'},
#  'roomname_1.029A': {'comment': 'room'},
#  'device_C2F7D4': {},
#  'zone_VL-F6-W1-A-13-B': {'comment': 'support_zone'},
#  'zone_VL-F7-O3-W14': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:90cb6d61-331e-46e9-95d0-ec9742c4e78d': {},
#  'roomname_1.038': {'comment': 'room'},
#  'device_urn:Device:SmartThings:805af131-e213-4885-b50a-c4e11d91680f': {},
#  'zone_VL-F7-W1-T20': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:a511fbe2-55b6-44e5-87fa-73fd6d2cd6b0': {},
#  'zone_VL-F2-W-W38': {'comment': 'support_zone'},
#  'R5_101': {},
#  'roomname_2.008': {'comment': 'room'},
#  'zone_VL-F3-W1-M21': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:088279bc-e450-4f71-aff9-d66eb1aa1b6e': {},
#  'R5_141': {},
#  'zone_VL-F3-W1-T1A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:fec9249f-0355-4e57-93bc-d080874e372e': {},
#  'zone_VL-F4-O3_-19': {'comment': 'support_zone'},
#  'R5_65': {},
#  'roomname_7.039': {'comment': 'room'},
#  'device_urn:Device:SmartThings:94e1096f-8482-4e0b-8fff-3bbae73fb1d4': {},
#  'device_urn:Device:SmartThings:36104049-82ca-44ef-9333-78bc38b1f7b1': {},
#  'roomname_3.077': {'comment': 'room'},
#  'zone_VL-F7-O3-W12': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-M5': {'comment': 'support_zone'},
#  'R5_199': {},
#  'zone_VL-F7-O4-W46': {'comment': 'support_zone'},
#  'zone_VL-F4-O3-W11A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:0d7076c0-44d4-495c-bf63-47c046d20caa': {},
#  'zone_VL-F6-W1-A-25': {'comment': 'support_zone'},
#  'zone_VL-F1-O2-T8': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e3163067-de01-458b-9fcb-e6f1b32e3212': {},
#  'zone_VL-F6-O3HUB': {'comment': 'support_zone'},
#  'zone_VL-F7-O4-T46': {'comment': 'support_zone'},
#  'R5_22': {},
#  'zone_VL-F3-O2-A-4': {'comment': 'support_zone'},
#  'zone_VL-F4-W1B-T12': {'comment': 'support_zone'},
#  'zone_VL-F2-O1-W2': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-W-76': {'comment': 'support_zone'},
#  'SmartSense_Multi_Sensor_73': {},
#  'zone_VL-F7-West-11': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:df5be664-9d1b-4ef5-87b4-9ab4bffc79fe': {},
#  'roomname_3.075': {'comment': 'room'},
#  'zone_VL-F2-O2-A-13': {'comment': 'support_zone'},
#  'zone_VL-F7-W1-M14': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-A-28': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:de1eaa0d-c38c-49b3-81b6-8511d356358c': {},
#  'roomname_4.07': {'comment': 'room'},
#  'device_urn:Device:SmartThings:bdf07bf6-c47d-4b2f-9caf-c5c56f20848b': {},
#  'zone_VL-F1-O3-M11': {'comment': 'support_zone'},
#  'zone_VL-F7-West-18': {'comment': 'support_zone'},
#  'zone_VL-F4-O4-W32': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e7d3aa2a-0a2b-410b-83be-3aa23088a6ce': {},
#  'R5_191': {},
#  'zone_VL-F6-O4-A-45': {'comment': 'support_zone'},
#  'zone_VL-F5-Oost-1__Kamer_Nummer__klient_2': {'comment': 'support_zone'},
#  'device_C30757': {},
#  'zone_VL-F1-O2-A-24': {'comment': 'support_zone'},
#  'roomname_7.027': {'comment': 'room'},
#  'zone_VL-F5-WEST-A-12139': {'comment': 'support_zone'},
#  'zone_VL-F3-O2-T8': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:97e04441-b83d-465c-b882-b5fd1a8021f7': {},
#  'zone_videolab-priva-controller102-floor2-right': {'comment': 'support_zone'},
#  'device_videolab-priva-controller102-floor2-right': {},
#  'roomname_1.036': {'comment': 'room'},
#  'R5_224': {},
#  'device_urn:Device:SmartThings:19aa2982-7e51-4ad3-b483-f5be7a808b00': {},
#  'zone_VL-F2-W-M41': {'comment': 'support_zone'},
#  'zone_VL-F3-O3-T13': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e743a5a3-b986-4e35-ad58-4f483b09484d': {},
#  'zone_videolab-priva-controller102-floor7-righ': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:31450e92-97ba-4d20-bcaa-a4b3f1a9729f': {},
#  'zone_VL-F4-W1B-W25': {'comment': 'support_zone'},
#  'roomname_2.079': {'comment': 'room'},
#  'device_urn:Device:SmartThings:cb46d3f1-7b94-471c-a121-d8c8c376ea86': {},
#  'zone_VL-F1-O2-T2': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:ba6c1e8c-884c-45b2-8310-32d571a045db': {},
#  'zone_VL-F7-Oost-56': {'comment': 'support_zone'},
#  'device_C2F7EF': {},
#  'zone_VL-F7-W1-W23': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:13acff39-267c-444c-bff0-e63e8b2cb7c4': {},
#  'zone_VL-F4-O3_-22': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-M39': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-M29': {'comment': 'support_zone'},
#  'device_C46ED1': {},
#  'zone_VL_-F4-W1B-42': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:efd997c5-76dc-4286-a638-1bf2779272bd': {},
#  'device_urn:Device:SmartThings:2ca6598a-5554-4e8b-8c64-faacc6112510': {},
#  'zone_VL-F6-03-W41B': {'comment': 'support_zone'},
#  'zone_VL-F2-O3-W53': {'comment': 'support_zone'},
#  'zone_VL-F7-W1-W1': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:73d0b4e4-9d5c-4a21-9bf7-4120fc636290': {},
#  'device_urn:Device:SmartThings:ea96b0b7-3837-4304-bfe2-32fca61eb567': {},
#  'zone_VL-F5-WEST-T72': {'comment': 'support_zone'},
#  'zone_VL-F1-W1-W37': {'comment': 'support_zone'},
#  'zone_VL-F3-O3-A-27': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:bb83dccd-60df-4d1c-8a91-a92f655c27a0': {},
#  'zone_VL-F7-W1-W9A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:2706f00d-61af-4770-a628-95e0bb913345': {},
#  'zone_VL-F3-O4-M36': {'comment': 'support_zone'},
#  'zone_VL-F2-O-W9': {'comment': 'support_zone'},
#  'zone_VL-F7-O4-W47': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-T28': {'comment': 'support_zone'},
#  'zone_VL-F3-O3-A-28': {'comment': 'support_zone'},
#  'zone_VL-F4-O4-W42': {'comment': 'support_zone'},
#  'SmartSense_Multi_Sensor_89': {},
#  'zone_VL-F2-W-T38': {'comment': 'support_zone'},
#  'zone_VL-F7-West-17': {'comment': 'support_zone'},
#  'device_C2FA17': {},
#  'roomname_2.003': {'comment': 'room'},
#  'device_urn:Device:SmartThings:28c84a63-3be1-4f02-8ec8-b4f7e91928d1': {},
#  'roomname_7.056': {'comment': 'room'},
#  'zone_VL-F1-O4-T51': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e75b004e-a25f-4531-9c47-29d323edaba3': {},
#  'zone_VL-F3-O4-M34': {'comment': 'support_zone'},
#  'zone_VL-F4-O3-M31': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:cc7e4c5e-8321-4dbb-8e0c-205cdaea8f29': {},
#  'zone_VL-F1-O4-M51': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:86f313f7-7440-4a3a-872f-2f4f2e371452': {},
#  'roomname_1.007': {'comment': 'room'},
#  'device_urn:Device:SmartThings:ca61c6cf-278a-4ec7-99f8-9bb5afc11e66': {},
#  'zone_VL-F2-O-T16B': {'comment': 'support_zone'},
#  'roomname_3.025': {'comment': 'room'},
#  'zone_VL-F6-O2-A-3': {'comment': 'support_zone'},
#  'R5_103': {},
#  'zone_VL_-F4-W1B-25': {'comment': 'support_zone'},
#  'SmartSense_Multi_Sensor_90': {},
#  'zone_VL-F5-OOST-W-23': {'comment': 'support_zone'},
#  'zone_VL-F7-West-16': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:54dcdb75-fc1f-46bf-9187-e730d9011f23': {},
#  'zone_VL-F4-O2-W5': {'comment': 'support_zone'},
#  'zone_VL-F7-O2-M7': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-A-3': {'comment': 'support_zone'},
#  'zone_VL-F3-O4-A-39': {'comment': 'support_zone'},
#  'R5_194': {},
#  'device_urn:Device:SmartThings:3a4bcd0f-54aa-46ac-bb3b-792d6479927c': {},
#  'roomname_2.03': {'comment': 'room'},
#  'device_urn:Device:SmartThings:6d53043b-f77e-4c96-8083-512b9ca6a25b': {},
#  'zone_VL-F3-W1-T9': {'comment': 'support_zone'},
#  'zone_VL-F4-O2-M24': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:5105d24d-1b69-4a91-af60-ade9d36d8bd8': {},
#  'zone_VL-F3-O3-T10': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:04927462-3f3f-465a-ab66-577f3ae97ad5': {},
#  'device_urn:Device:SmartThings:d20bdbdb-c8bd-4ca5-b6ff-b48d2625658d': {},
#  'zone_VL-F6-O2-M1': {'comment': 'support_zone'},
#  'zone_VL-F3-O2-A-7': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:a9d71db1-b639-4402-bea0-7bfdbead940e': {},
#  'device_C2FE73': {},
#  'zone_VL-F2-W4-37': {'comment': 'support_zone'},
#  'roomname_2.002A': {'comment': 'room'},
#  'zone_VL-F1-O2-M8': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-M32': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:4cbbd43d-bcee-43a0-adc7-e2fe7031947d': {},
#  'roomname_7.055': {'comment': 'room'},
#  'device_urn:Device:SmartThings:435ded01-0d0b-44d5-ba39-29557804c61d': {},
#  'device_urn:Device:SmartThings:0a69ef31-38f1-4210-8732-6a328897bc94': {},
#  'zone_VL-F1-O3-W11': {'comment': 'support_zone'},
#  'roomname_7.022A': {'comment': 'room'},
#  'device_urn:Device:SmartThings:21921699-dd1f-424f-907e-c3f8da77f1ce': {},
#  'zone_VL-F6-W1-T32': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:d84bb27e-20e9-482d-b79c-21a5b95a9524': {},
#  'zone_VL-F7-O4-M50': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:7291a9e3-c4b8-4e73-bd0c-fd06506a9131': {},
#  'zone_VL-F2-W-W5': {'comment': 'support_zone'},
#  'zone_VL-F2-O1-A-22': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:0bc50f19-dbd5-4967-b75e-676e5cc42885': {},
#  'zone_VL-F5-OOST-W-15': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-M18': {'comment': 'support_zone'},
#  'device_C2E89D': {},
#  'device_urn:Device:SmartThings:cb429251-88e8-45c0-bbdd-aff4d1d0f2c8': {},
#  'zone_VL-F4-O4-T38': {'comment': 'support_zone'},
#  'zone_VL-F2-O3-T52': {'comment': 'support_zone'},
#  'zone_VL-F2-W-M32A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:ab6e09bc-0182-482e-ae10-5bd6c51e1fb4': {},
#  'zone_VL-F7-O4-W48': {'comment': 'support_zone'},
#  'roomname_1.055': {'comment': 'room'},
#  'zone_VL-F5-WEST-M-44': {'comment': 'support_zone'},
#  'R5_223': {},
#  'zone_VL-F2-W-T12B': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:a8b0dd72-b0b0-4316-b76a-4b279a5dfa2d': {},
#  'R5_146': {},
#  'roomname_2.002': {'comment': 'room'},
#  'zone_VL-F1-O3-M40-A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:59ab27c3-b185-4b3d-a32e-173ddbefa5b6': {},
#  'zone_VL-F2-W-M25': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:bccc66a1-780d-4812-984d-c7f7c5952a8f': {},
#  'zone_VL-F2-W-T13B': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:f338321f-b83c-46c8-8ef5-9d69c0985a5b': {},
#  'roomname_7.011': {'comment': 'room'},
#  'device_urn:Device:SmartThings:25219240-83ae-4208-8d47-e7a61da0523e': {},
#  'device_urn:Device:SmartThings:425711b8-e1a4-496a-9397-2dca20c42e61': {},
#  'zone_VL-F4-W1A-W30b': {'comment': 'support_zone'},
#  'zone_VL-F2-O-M40': {'comment': 'support_zone'},
#  'zone_VL-F3-O4-A-40': {'comment': 'support_zone'},
#  'R5_186': {},
#  'zone_VL-F7-O2-T2': {'comment': 'support_zone'},
#  'roomname_2.077': {'comment': 'room'},
#  'device_urn:Device:SmartThings:65f10f86-8bd2-4f66-8a5a-b060d416f279': {},
#  'zone_VL-F7-O3-M38': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:a6be22aa-3b73-4f91-b535-dd1e0ee90d04': {},
#  'roomname_1.024': {'comment': 'room'},
#  'zone_VL-F2-W-T9': {'comment': 'support_zone'},
#  'zone_VL-F7-O4-M49': {'comment': 'support_zone'},
#  'zone_VL-F2-O3-A-48': {'comment': 'support_zone'},
#  'zone_VL-F5-OOST-T-19': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:effa98eb-2753-468e-8a04-1baee150a65b': {},
#  'zone_VL-F6-W1-W1A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:bf4e7f57-5e42-4676-bbc0-5b957a9c686b': {},
#  'roomname_7.036': {'comment': 'room'},
#  'zone_VL-F3-W1-M9': {'comment': 'support_zone'},
#  'roomname_2.037': {'comment': 'room'},
#  'R5_115': {},
#  'zone_VL-F2-O1-M7': {'comment': 'support_zone'},
#  'zone_VL_-F4-W1B-34': {'comment': 'support_zone'},
#  'zone_VL-F4-W1B-M11': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:bcd66234-37c4-4158-a2fa-8f43a83fdf19': {},
#  'zone_VL-F7-Oost-34': {'comment': 'support_zone'},
#  'zone_VL-F3-W1-T13C': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:5dc92927-e07f-4338-bb72-30e794643546': {},
#  'zone_VL-F7-O4-M53': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:70b55985-373a-4e55-96db-4593b829d3e2': {},
#  'device_urn:Device:SmartThings:c964e2bc-35b0-4d73-b735-e58c23b36103': {},
#  'zone_VL-F2-O3-M45': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:db13289c-912f-4c05-904d-e3c78cc81d52': {},
#  'zone_VL-F5-OOST-T-8': {'comment': 'support_zone'},
#  'zone_VL-F1-W1-M36': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:97744bd4-444e-4be4-aeeb-40ed8ab02304': {},
#  'device_urn:Device:SmartThings:683eab0f-a5b8-48a5-84e7-0d6e30df1597': {},
#  'zone_VL-F6-W1-T1': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:6edeb85b-3e49-45f5-8e17-14535e3fa8ea': {},
#  'roomname_4.062A': {'comment': 'room'},
#  'SmartSense_Motion_Sensor_13': {},
#  'roomname_4.018': {'comment': 'room'},
#  'zone_VL-F2-O-M31': {'comment': 'support_zone'},
#  'R5_92': {},
#  'device_urn:Device:SmartThings:1627d2f5-e0c8-417c-ac78-a2c3eba44ef7': {},
#  'device_urn:Device:SmartThings:a6196405-8ee6-432f-afbb-d3b15b5e0a2d': {},
#  'zone_VL-F4-O4-T32': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:727f089a-04ec-4756-b804-fd3a520e94de': {},
#  'zone_VL-F3-O2-M2': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:2bb1662a-21be-432a-8b38-1af30c988468': {},
#  'device_urn:Device:SmartThings:0af05b98-7be3-4d3f-b7a6-03233a93e5fc': {},
#  'zone_VL-F4-W1A-M50': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:4faf5de7-0775-40b5-a6ca-a292405358a9': {},
#  'zone_VL-F3-O2-M3': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:3f7d0b5f-dce8-498c-b016-f17b72ef8d34': {},
#  'device_urn:Device:SmartThings:a96ffe22-8d9a-4786-9e95-265b8479562e': {},
#  'roomname_4.038': {'comment': 'room'},
#  'device_urn:Device:SmartThings:4d578e7d-75a9-4daf-9089-674bce82fb3d': {},
#  'roomname_2.002G': {'comment': 'room'},
#  'device_C34F51': {},
#  'zone_VL-F4-_W1A_-_1': {'comment': 'support_zone'},
#  'R5_44': {},
#  'zone_VL-F3-O3-A-32': {'comment': 'support_zone'},
#  'R5_43': {},
#  'zone_VL-F4-O2-W1': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:2f178ce2-fb94-444d-839b-c8a340d748b3': {},
#  'zone_VL-F1-O2-M2': {'comment': 'support_zone'},
#  'zone_VL-F7-Oost-53': {'comment': 'support_zone'},
#  'device_C3146E': {},
#  'SmartSense_Motion_Sensor_32': {},
#  'zone_VL-F1-O2-M36': {'comment': 'support_zone'},
#  'device_C46F96': {},
#  'roomname_2.002E': {'comment': 'room'},
#  'zone_VL-F2-W-T7': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:c4cdd22a-4436-4011-90f6-9d4e556160c8': {},
#  'zone_VL-F4-W1B-M36': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-M31': {'comment': 'support_zone'},
#  'zone_VL-F1-O4-T47': {'comment': 'support_zone'},
#  'zone_VL-F3-O3-M29': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-W31-A': {'comment': 'support_zone'},
#  'zone_VL-F1-O4-T41': {'comment': 'support_zone'},
#  'zone_VL-F6-04-W47': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:ed52eb18-8dec-4e3d-8c2a-7cce09bbd3cb': {},
#  'zone_Verdieping_5': {'comment': 'support_zone'},
#  'zone_VL-F7-O3-M9': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:8525abcb-c5d6-4d8b-a849-1240990ca3b2': {},
#  'roomname_7.002': {'comment': 'room'},
#  'SmartSense_Multi_Sensor_47': {},
#  'zone_VL-F4-_W1A_-_52': {'comment': 'support_zone'},
#  'zone_VL-F4-O3_-17': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-A-32': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:d7121064-a111-46ee-8b5b-ff61d7845b7e': {},
#  'device_urn:Device:SmartThings:ddda3f92-7e8b-41c1-bdd3-333aee323b18': {},
#  'zone_VL-F1-O4-T45': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:187ce571-ebdf-4494-8523-63882f4abeaa': {},
#  'zone_VL-F4-W1A-M16': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-A-33': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-W-71': {'comment': 'support_zone'},
#  'roomname_3.053': {'comment': 'room'},
#  'roomname_1.077': {'comment': 'room'},
#  'SmartSense_Multi_Sensor_6': {},
#  'roomname_1.011': {'comment': 'room'},
#  'device_urn:Device:SmartThings:535c6aec-fc33-4cdf-92e6-573798a009d1': {},
#  'roomname_7.003': {'comment': 'room'},
#  'device_urn:Device:SmartThings:8b38d07d-599b-4fd1-8195-83c2662acc7d': {},
#  'roomname_7.007': {'comment': 'room'},
#  'zone_VL-F6-04-M48': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:0d517786-c9ee-452f-9460-4a9210f5d310': {},
#  'zone_VL-F4-W1A-M30': {'comment': 'support_zone'},
#  'zone_VL-F2-W-W42': {'comment': 'support_zone'},
#  'zone_VL-F6-O3-A-35': {'comment': 'support_zone'},
#  'device_C455FB': {},
#  'zone_Verdieping_4_Oostvleugel': {'comment': 'support_zone'},
#  'zone_VL-F6-W1-M25': {'comment': 'support_zone'},
#  'SmartSense_Motion_Sensor_28': {},
#  'roomname_4.06': {'comment': 'room'},
#  'device_videolab-priva-controller102-floor7-left': {},
#  'zone_videolab-priva-controller102-floor7-left': {'comment': 'support_zone'},
#  'zone_VL-F2-W-M9': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:b1531d7d-314b-41d9-a675-a3319e4a7c04': {},
#  'device_urn:Device:SmartThings:437383f5-2102-4959-b1a4-b13720251f1d': {},
#  'roomname_2.036': {'comment': 'room'},
#  'zone_VL-F4-W1A-T30a': {'comment': 'support_zone'},
#  'zone_VL-F6-O4-A-47': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:33e8a5f5-1f06-4a66-9622-9e75ce4636b1': {},
#  'zone_VL-F6-W1-M23': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:69f43db0-1c1b-4be7-b659-bfb116d11292': {},
#  'zone_VL-F3-W1-A-29': {'comment': 'support_zone'},
#  'zone_VL-F2-O-M32': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:ec7ca89f-0ac4-40f0-a40d-68a941764663': {},
#  'device_C2FC42': {},
#  'roomname_1.057': {'comment': 'room'},
#  'R5_168': {},
#  'device_urn:Device:SmartThings:fe5aba61-750f-4a24-9979-a0d2f599b9ac': {},
#  'zone_VL-F6-O2-M22': {'comment': 'support_zone'},
#  'zone_VL-F6-O3-A-13': {'comment': 'support_zone'},
#  'R5_23': {},
#  'zone_VL-F6-W1-M3': {'comment': 'support_zone'},
#  'R5_198': {},
#  'roomname_2.042': {'comment': 'room'},
#  'roomname_3.076': {'comment': 'room'},
#  'R5_155': {},
#  'roomname_1.032': {'comment': 'room'},
#  'device_urn:Device:SmartThings:71ce3270-28ae-42ad-8630-eebc86a2facc': {},
#  'zone_VL-F7-Oost-17': {'comment': 'support_zone'},
#  'zone_VL-F2-O2-W14': {'comment': 'support_zone'},
#  'zone_Verdieping_7_Oostvleugel': {'comment': 'support_zone'},
#  'R5_2': {},
#  'zone_VL-F4-W1B-M41': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:2d26489e-6e12-457a-9151-b0402414113f': {},
#  'zone_VL-F2-O3-T48': {'comment': 'support_zone'},
#  'roomname_7.016': {'comment': 'room'},
#  'roomname_4.040A': {'comment': 'room'},
#  'zone_VL-F4-_W1A_-_49': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:cb155782-16a4-4785-89e5-3f1ce514f0d7': {},
#  'zone_VL-F6-O2-A-7': {'comment': 'support_zone'},
#  'zone_VL-F3-W1-M13': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:169d8b59-0112-481e-a984-d45e00159380': {},
#  'device_urn:Device:SmartThings:78cc6041-3fe1-4af4-8ac3-d0c8aa079eb9': {},
#  'zone_VL-F6-04-M43': {'comment': 'support_zone'},
#  'zone_VL-F2-O1-W8': {'comment': 'support_zone'},
#  'zone_VL-F7-Oost-1': {'comment': 'support_zone'},
#  'zone_VL-F7-O4-T53': {'comment': 'support_zone'},
#  'zone_videolab-F4-Oost-Hub4': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:7fbfe7a0-5cf3-43eb-87d1-bbe888a5eb19': {},
#  'zone_VL-F4-W1B-M7': {'comment': 'support_zone'},
#  'zone_Verdieping_7_Westvleugel': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:cba5e962-fb26-4d74-bac4-8ac22d03375f': {},
#  'zone_VL-F6-02-M3': {'comment': 'support_zone'},
#  'SmartSense_Motion_Sensor_27': {},
#  'roomname_2.002F': {'comment': 'room'},
#  'device_urn:Device:SmartThings:7970256c-3441-43d1-838f-a0e5b837b7e8': {},
#  'device_urn:Device:SmartThings:b2d4f64f-8961-4422-8525-39c4742c92b4': {},
#  'zone_VL-F7-W1-T6': {'comment': 'support_zone'},
#  'zone_VL-F1-O3-M37-A': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:22d49092-954c-4abe-980a-c4daab065b93': {},
#  'zone_VL-F5-WEST-M-63': {'comment': 'support_zone'},
#  'SmartSense_Motion_Sensor_31': {},
#  'zone_VL-F6-O3-T14': {'comment': 'support_zone'},
#  'zone_VL-F3-O3-T11': {'comment': 'support_zone'},
#  'zone_VL-F4-W1A-M32': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:7adf3e24-3246-402b-a1eb-bb157aa70ad3': {},
#  'roomname_2.009': {'comment': 'room'},
#  'roomname_3.074': {'comment': 'room'},
#  'device_C40B21': {},
#  'zone_VL-F2-O-T16A': {'comment': 'support_zone'},
#  'zone_VL-F3-O4-M37': {'comment': 'support_zone'},
#  'zone_VL-F6-O3-M9': {'comment': 'support_zone'},
#  'zone_VL-F3-W1-13A': {'comment': 'support_zone'},
#  'zone_VL-F6-O2-W6': {'comment': 'support_zone'},
#  'device_C30DF0': {},
#  'zone_VL-F7-Oost-51': {'comment': 'support_zone'},
#  'zone_VL-F4-W1A-M46': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:88a52f87-e967-4cd1-86fa-d33cb7776645': {},
#  'device_urn:Device:SmartThings:d10d7212-344e-4f3c-bfab-e31c0125edf4': {},
#  'device_urn:Device:SmartThings:80f468a7-0b9f-44b9-8fa0-98aa3bb3fc3b': {},
#  'device_urn:Device:SmartThings:b1d48664-d94b-40e5-8e48-c8152919f495': {},
#  'zone_VL-F6-W1-T25': {'comment': 'support_zone'},
#  'zone_VL-F1-W1-A-30': {'comment': 'support_zone'},
#  'zone_VL-F3-W1-A-24': {'comment': 'support_zone'},
#  'roomname_2.074': {'comment': 'room'},
#  'device_urn:Device:SmartThings:9f01c138-d8df-4df4-aaa6-4a8b93db90d6': {},
#  'zone_VL-F6-O3-M40': {'comment': 'support_zone'},
#  'zone_VL-F3-W1-M22': {'comment': 'support_zone'},
#  'zone_VL-F5-WEST-T-53': {'comment': 'support_zone'},
#  'zone_VL-F7-West-22': {'comment': 'support_zone'},
#  'device_C2F378': {},
#  'R5_18': {},
#  'device_C316A3': {},
#  'R5_10': {},
#  'device_urn:Device:SmartThings:2dcc7801-5a60-4c0c-9343-97857e85e7e6': {},
#  'zone_VL-F2-O-T11': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:e8a1889f-2259-4b95-9308-fd6a6cde45ab': {},
#  'zone_VL-F1-W1-T40': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:90f96a39-f394-4090-931d-2e678bef1524': {},
#  'R5_91': {},
#  'device_urn:Device:SmartThings:f917d843-a05d-464a-b477-4b526816db98': {},
#  'roomname_3.013': {'comment': 'room'},
#  'device_urn:Device:SmartThings:a498c0b3-2a8c-4684-bb8d-cf3603309764': {},
#  'roomname_4.074': {'comment': 'room'},
#  'device_urn:Device:SmartThings:1ac49e79-fd98-4789-9583-3d10870657e8': {},
#  'zone_VL-F6-W1-M14-A': {'comment': 'support_zone'},
#  'zone_VL-F2-O-W10': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:56b22e24-074a-4d18-9e8a-b31980bcd1fd': {},
#  'device_urn:Device:SmartThings:f987aca6-afd2-4227-9391-2be59cb16d2c': {},
#  'zone_VL-F1-W1-W38': {'comment': 'support_zone'},
#  'SmartSense_Multi_Sensor_23': {},
#  'zone_VL-F5-WEST-W-75': {'comment': 'support_zone'},
#  'zone_VL-F4-O3-M22': {'comment': 'support_zone'},
#  'roomname_3.008': {'comment': 'room'},
#  'device_urn:Device:SmartThings:eff97988-a4f5-4bf7-acba-ce29f3468d45': {},
#  'device_urn:Device:SmartThings:bc77d7fb-16ea-49f5-9656-427dd62efdfa': {},
#  'device_urn:Device:SmartThings:2f998d78-3e5b-47e3-a17a-1d2d06b7f93f': {},
#  'zone_VL-F1-O4-W45': {'comment': 'support_zone'},
#  'roomname_3.02': {'comment': 'room'},
#  'Zigbee_Thermostat_14': {},
#  'zone_VL-F3-O4-M39': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:afb75c1c-09cd-4e00-b7bd-dd0de54cb933': {},
#  'zone_VL-F2-O3-T44': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:1656b14b-c420-4033-bbc7-87d80205f0b6': {},
#  'device_urn:Device:SmartThings:399976e0-91c4-4c9e-a9b4-e549faaab2b1': {},
#  'zone_VL-F5-OOST-T-4': {'comment': 'support_zone'},
#  'device_urn:Device:SmartThings:b1f3e46f-c123-4495-a1b2-6cf67db89701': {},
#  'zone_videolab-priva-controller102-floor5-right': {'comment': 'support_zone'},
#  'zone_VL-F4-O4-W37': {'comment': 'support_zone'},
#  'zone_VL_-F2-O1-A-19-B': {'comment': 'support_zone'},
#  'zone_VL-F2-W-W37': {'comment': 'support_zone'},
#  'zone_VL-F3-W1-M28': {'comment': 'support_zone'},
#  ...}
